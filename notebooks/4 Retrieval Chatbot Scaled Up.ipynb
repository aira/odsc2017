# %%
import pandas as pd
np = pd.np
pd.set_option('display.max_rows', 4)
pd.set_option('display.max_columns', 500)

from IPython.display import display, HTML
import seaborn as sns
from seaborn.utils import plt

# display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML(open("../shared-resources/jupyter.css", "r").read()))
# %matplotlib inline
# import mpld3

sns.mpl.rc("figure", figsize=(16, 6))
# plt.style.use('seaborn')
# plt.rc("figure", figsize=(16, 6))
# mpld3.enable_notebook()


from nlpia.data.loaders import get_data
# Out:
# <style>
#     .container {
#         width: 99%;
#     }
#     div.cell{
#         width: 99%;
#         margin-left: 1%;
#         margin-right: auto;
#     }
#     div.cell.selected {
#         border-left-width: 1px;
#     }
# </style>

# %%
df = get_data('ubuntu_dialog')
df.head()
# Out:
# Downloading ubuntu_dialog
# requesting URL: https://www.dropbox.com/s/krvi79fbsryytc2/ubuntu_dialog.csv.gz?dl=1
# remote size: 296098788
# local size: 296098788
#                                               Context  \
# 0   i think we could import the old comments via r...
# 1   I'm not suggesting all - only the ones you mod...
# ..                                                ...
# 3   interesting __eou__ grub-install worked with /...
# 4   and because Python gives Mark a woody __eou__ ...
#
#                                             Utterance
# 0   basically each xfree86 upload will NOT force u...
# 1                                   oh? oops. __eou__
# ..                                                ...
# 3   i fully endorse this suggestion </quimby> __eo...
# 4   (i thought someone was going to make a joke ab...
#
# [5 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499744 entries, 0 to 1999998
# Data columns (total 2 columns):
# Context      1499744 non-null object
# Utterance    1499744 non-null object
# dtypes: object(2)
# memory usage: 34.3+ MB

# %%
len(df)
# Out:
# 1499744

# %%
h = pd.DataFrame(index=df.index)
h['context_len'], h['utterance_len'] = df.Context.str.len(), df.Utterance.str.len()
print(h.min().min(), h.max().max())
h.describe().T
# Out:
# 8 10835
#                    count        mean         std   min    25%    50%    75%  \
# context_len    1499744.0  489.090587  404.449046  36.0  218.0  362.0  619.0
# utterance_len  1499744.0   85.485046   79.375129   8.0   34.0   64.0  111.0
#
#                    max
# context_len    10835.0
# utterance_len   3154.0

# %%
bins = np.arange(41) * (h.max().max() - h.min().min()) / 40. + h.min().min()
print(bins)

fig = plt.figure()
ax = fig.subplots()
for c in h.columns:
    ax = sns.distplot(h[c], bins=bins, ax=ax, kde=False)
plt.legend(h.columns)
plt.yscale = 'log'
# Out:
# [  8.00000000e+00   2.78675000e+02   5.49350000e+02   8.20025000e+02
#    1.09070000e+03   1.36137500e+03   1.63205000e+03   1.90272500e+03
#    2.17340000e+03   2.44407500e+03   2.71475000e+03   2.98542500e+03
#    3.25610000e+03   3.52677500e+03   3.79745000e+03   4.06812500e+03
#    4.33880000e+03   4.60947500e+03   4.88015000e+03   5.15082500e+03
#    5.42150000e+03   5.69217500e+03   5.96285000e+03   6.23352500e+03
#    6.50420000e+03   6.77487500e+03   7.04555000e+03   7.31622500e+03
#    7.58690000e+03   7.85757500e+03   8.12825000e+03   8.39892500e+03
#    8.66960000e+03   8.94027500e+03   9.21095000e+03   9.48162500e+03
#    9.75230000e+03   1.00229750e+04   1.02936500e+04   1.05643250e+04
#    1.08350000e+04]

# %%
from gensim.corpora import Dictionary, TextCorpus, MmCorpus
from gensim.models import LsiModel, TfidfModel
from nltk.tokenize.casual import TweetTokenizer
# from tqdm import tqdm

# %%
import re
from itertools import chain

splitter = re.compile(r'__eo[a-z]__') 
for sent in chain.from_iterable(splitter.split(df.Context.iloc[i]) for i in range(3)):
    if len(sent.strip()):
        print(sent)
# Out:
# i think we could import the old comments via rsync, but from there we need to go via email. I think it is easier than caching the status on each bug and than import bits here and there
#  it would be very easy to keep a hash db of message-ids
#  sounds good
#  ok
#  perhaps we can ship an ad-hoc apt_prefereces
#  version?
#  thanks
#  not yet
#  it is covered by your insurance?
#  yes
#  but it's really not the right time :/
#  with a changing house upcoming in 3 weeks
#  you will be moving into your house soon?
#  posted a message recently which explains what to do if the autoconfiguration does not do what you expect
#  how urgent is #896?
#  not particularly urgent, but a policy violation
#  i agree that we should kill the -novtswitch
#  ok
#  would you consider a package split a feature?
#  context?
#  splitting xfonts* out of xfree86*. one upload for the rest of the life and that's it
#  splitting the source package you mean?
#  yes. same binary packages.
#  I would prefer to avoid it at this stage.  this is something that has gone into XSF svn, I assume?
# I'm not suggesting all - only the ones you modify.
#  ok, it sounds like you're agreeing with me, then
#  though rather than "the ones we modify", my idea is "the ones we need to merge"
# afternoon all
#  not entirely related to warty, but if grub-install takes 5 minutes to install, is this a sign that i should just retry the install :)
#  here
#  you might want to know that thinice in warty is buggy compared to that in sid
#  and apparently GNOME is suddently almost perfect (out of the thinice problem), nobody report bugs :-P
#  I don't get your question, where do you want to paste ?
#  can i file the panel not linking to eds? :)
#  are you using alt ? or the windows key ?
#  wait for the gnome-themes, component will be added
#  i just restarted X and now nautilus won't show the desktop :(
#  hal isn't starting :(
#  do you think we have any interest to have hal support turned on in gnome-vfs at this point ? It increases the sources of problems for no real benefit imho ...
#  is it a known bug that g-s-t doesn't know what distribution its running on?
#  are there any changes to desktop-file-utils you've got hidden away?
#  somebody should really kick that guy *hard*
#  I've added a build-dep on libxt-dev in warty for zenity
#  arse. xt-dev? i added libx11-dev
#  so just libxt-dev or libxt and libx11?
#  for future note, the xmodmap line in that X sticky-super fixes the problem for me
#  we have planned to speak about menu organisation during the 2 weeks
#  I need we don't need to force it
#  ?
#  was away, you said ?
#  nope
#  the warty repository
#  ok, fine. Thanks
#  nice to get packages update every 30min instead once a day, isn't it :)
#  you'll be glad to know i've fixed my missing arrows in thinice bug
#  I've uploaded the gnome-vfs without hal support should be available rsn
#  should g2 in ubuntu do the magic dont-focus-window tricks?
#  join the gang, get an x-series thinkpad
#  sj has hung on my box, again.
#  what is monday mornings discussion actually about?

# %%
import re
from itertools import chain 

def split_eou(iterable, splitter=re.compile('__eo[a-z]__')):
    for utterance in chain.from_iterable(splitter.split(uts) for uts in iterable):
        if len(utterance.strip()):
            yield utterance

for ut in chain.from_iterable([split_eou(df.Context), split_eou(df.Utterance)]) :
    print(ut)
    break

texts = chain.from_iterable([split_eou(df.Context), split_eou(df.Utterance)])
# assert len(texts) == 2 * len(df)
# assert df.Context.str.contains('\n').sum() == 0
# assert df.Utterance.str.contains('\n').sum() == 0

TEXT_PATH = '../shared-resources/ubuntu_dialog.txt'  # file that will contain one document per line (), all statements, then all utterances
# Out:
# i think we could import the old comments via rsync, but from there we need to go via email. I think it is easier than caching the status on each bug and than import bits here and there

# %%
with open(TEXT_PATH, 'w') as fout:
    for i, text in enumerate(texts):
        fout.write(text + '\n')
print('Wrote {} lines to {}'.format(i + 1, TEXT_PATH))
del texts
del h
# Out:
# Wrote 12290390 lines to ../shared-resources/ubuntu_utterances.txt

# %%
class BOWCorpus(object):

    def __init__(self, file_path, vocab=None, dictionary=None, tokenizer=TweetTokenizer(preserve_case=True), batch_size=10000):
        self.file_path = file_path
        self.batch_size = batch_size
        self.vocab = vocab if vocab is not None else (dictionary if dictionary is not None else None)
        self.tokenizer = tokenizer if tokenizer is not None else TweetTokenizer(preserve_case=True)
        self.num_documents = 0

        if self.vocab is None:
            self.vocab = Dictionary()
            with open(self.file_path) as fin:
                batch = []
                for i, line in enumerate(fin):
                    if not ((i + 1) % self.batch_size):
                        self.vocab.add_documents(batch)
                        batch = []
                        print(i, line[:60])
                    batch = batch.append(line)
                    self.num_documents = i + 1
                if len(batch):
                    self.vocab.add_documents(batch)
                    batch = []
                    

    def __iter__(self):
        with open(self.file_path) as fin:
            for i, line in enumerate(fin):
                if not i % self.batch_size:
                    print(i, line[:60] + '...')
                # assume there's one document per line, tokens separated by whitespace
                yield self.vocab.doc2bow(self.tokenizer.tokenize(line))

# %%
bows = BOWCorpus(TEXT_PATH)
# Out:
# 0 i think we could import the old comments via rsync, but from
# 1000 hi there __eou__ anybody experienced trouble with sound  __e
# 2000 it could also be some element of the OBEX protocol niceties
# 3000 hey all...anybody know how to install some win codecs? __eou
# 4000 Whats the difference between universe and multiverse ? __eou
# 5000 does the default kernel have no loop iso mount support? __eo
# 6000 hello __eou__ so, if you install a package in ubuntu does it
# 7000 so why not use a 4 page disertation for the version "number"
# 8000 there is no good download manager? __eou__ __eot__ for what?
# 9000 hrmph -- so, I'm well along with my debian-to-ubuntu convers
# 10000 how fissy? __eou__ ehhh that was supposed to go to baluba __
# 11000 anyone? kernel source on ubuntu? __eou__ anyone? is there ke
# 12000 hrm __eou__ Why not optimise for i586/i686? __eou__ __eot__
# 13000 apt-get is getting really old stuff in my just installed ubu
# 14000 Anybody else here playing Quake 3? __eou__ __eot__ I played
# 15000 oof __eou__ don't forget the "will delete your user data" ca
# 16000 I can't get my linux supported usb hp officejet 5500 multifu
# 17000 hell0w again :D __eou__ Well i am :D __eou__ I wanna become
# 18000 excuse me folks, how can I direct ubuntu to use a static add
# 19000 Is it possible to mount an FTP Server like a network share?
# 20000 Hi! Does anyone manage to install Firefox 1 and Thunderbird
# 21000 is it easy to compile an up-to-date kernel for ubuntu? like
# 22000 Octane - does Alt-F2, get you to a promt? __eou__ Octane - I
# 23000 has anyone gotten kqemu to work in ubuntu? I'm a complete n0
# 24000 <gepp1> Does the Ubuntu apache2 binary have mod_rewrite enab
# 25000 gnome needs a bloat clean up __eou__ its a good desktop dont
# 26000 one thing i don't get. ubuntu has apt-get but when trying to
# 27000  :-) __eou__ __eot__ is that a good :-) ? or a guess what :-
# 28000 synaptic is included and installed by default in Ubuntu __eo
# 29000 heh - gee speaking of gnome.. is there a way to disable that
# 30000 gedit __eou__ __eot__ Jedit __eou__ __eot__
#
# 31000 Hi __eou__ Is there any way I can install a CMS on a local P
# 32000 dpkg --reconfigure Xfree86 ? __eou__ thanks thoreauputic.  :
# 33000 can anybody tell me why ClamAV or similar antivirus isn't in
# 34000 no, not really :) __eou__ I really wish I hadn't missed the
# 35000 no return key needed __eou__ __eot__ ah,, just wordwrap __eo
# 36000 <Burgundavia> omeg, Synaptic Package Manger <-- I've found A
# 37000 Is http://sourceforge.net completely dead for anyone else he
# 38000 does someone here streams audio on the net? __eou__ does som
# 39000 what's the structure of these heads? __eou__ __eot__ trying
# 40000 wtf... i try to add multiverse to my sources, and everytime
# 41000 does anybody know what package provides ft2build.h? __eou__
# 42000 tar xzvf tar ballname __eou__ tar xzvf tar_ballname rather _
# 43000 You are familiar with the concept of a wiki right? __eou__ _
# 44000 i need to post my wiki about network interfaces not getting
# 45000 how to install kde ? __eou__ __eot__ sudo apt-get update &&
# 46000 anyone know of a good notes manager / organizer  "tree" styl
# 47000 the apt-system isn't built for downgrades... __eou__ __eot__
# 48000 Hey, I was wondering whether any of you knew of a tool to ex
# 49000 I am trying to watch a video using MPlayer and I get very lo
# 50000 How do I set an icon to a file type globally? Instead of cha
# 51000 screw linspire, they CHARGE MONEY for gcc __eou__ It's free
# 52000 yes. :) __eou__ google.com/ig | my-live-journal | ubuntuforu
# 53000 has anyone heard of this problem I am having on my laptop ru
# 54000 hello ;) __eou__ __eot__ in a terminal do this 'sudo apt-cac
# 55000 is there a way to link the terminal copy and paste crap with
# 56000 [j] [a] [r] [e] [d] , did you try google? (I can't help you,
# 57000 did you recently add hard drives? the installer should find
# 58000 stay away from the 'guide, it is full of pitfalls __eou__ __
# 59000 commented __eou__ look at the bottom of php.ini __eou__ disg
# 60000 look for the version 1.0.4 __eou__ __eot__ "look for the ver
# 61000 what's the equivalent in ubuntu of the kernel-headers-xxx-x-
# 62000 Hello, /etc/X11/xkb/rules/xorg is a symlink to "base" __eou_
# 63000 hi! __eou__ any cron users here? __eou__ __eot__ All Ubuntu
# 64000 do you find you repeat a lot?...lol, don't ask to ask lol, h
# 65000 I wish I knew why fglrx doesn't let me use totem and mplayer
# 66000 dang its starting to feel like burger time __eou__ joose wha
# 67000 tiago,PM-aSeepin: Please keep the code of conduct in mind wh
# 68000 how can i see if my video dirvers are installed properly? __
# 69000 hmmm, to buy a XFX 6600GT or a X800GT , that is the question
# 70000 anyone has tried google talk with gaim? __eou__ __eot__ yup
# 71000 Anyone know of a good FTP client with SSL? __eou__ __eot__ g
# 72000 hello ...ppl.. __eou__ does somebody here has a package for
# 73000 Has anybody used skype on ubuntu? __eou__ __eot__ - I tried.
# 74000 hey all, when suing in terminal, it dosnt take the password,
# 75000 Hi, is grub actually able to boot a floppy image located on
# 76000 hi i'm back again .. installed bittornado .. but the command
# 77000 seems that gnomemeeting is similar to microsoft netmeeting f
# 78000 how to update breezy? is it in the repo? __eou__ or u have t
# 79000  yea slashdot was one of em __eou__ __eot__  ? __eou__ __eot
# 80000 nautilus is the filemanager for Gnome __eou__ __eot__  why t
# 81000 nvdia tnt2 model 64 at breezy, someone have problems? __eou_
# 82000 Hey all. __eou__ Question, is there any way to install witho
# 83000 anyone got the nvidia driver to compile? __eou__ __eot__ the
# 84000 hi @all __eou__ what about the breezy iptables-package?? mod
# 85000 HI, is there a way for me to create a complete perfect image
# 86000 no, the kernel was compiled with gcc-3.4 __eou__ because the
# 87000 What is the shell cmd to configure X ? __eou__ __eot__ sudo
# 88000 I need to add a resolution setting what file do I edit again
# 89000 I love Ubuntu but it's starting to give me a lot of problems
# 90000  how can i chroot a knoppix-cd? i have problem with the acpi
# 91000 Hi, dmesg tells me "Unknown key pressed (translated set 2, c
# 92000 if you want a standalone js interpreter try rhino __eou__ or
# 93000 maybe you need to install libsdl1.2debian-esd, that works fo
# 94000 a compile of mine is trying to find libcurses __eou__ i cant
# 95000 u on? __eou__ __eot__ you mean "Can someone tell me where on
# 96000 have you tried using gedit to convert the encoding? under th
# 97000 I need to reconfigure xserver to use a different resolution.
# 98000 will that work ok for my amd64? __eou__ __eot__  sudo wget h
# 99000 sup __eou__ is knubuntu just ubuntu with KDE or its own CDs
# 100000 hello __eou__ I have a problem with VMware on Breezy. The Ne
# 101000 I need same kind of image viewer programm which makes possib
# 102000 How do I disable the GNOME startup sound? __eou__ __eot__ th
# 103000 Hey, has anyone got Azureus installed alongsie Eclipse? __eo
# 104000 How do I find out if ubuntu supports my hardware? __eou__ __
# 105000 ARGH! __eou__ HATE HATE HATE HATE __eou__ Firefox needs to h
# 106000 ] Kem[,  I recomment easybreezy also __eou__ ] Kem[,  You mi
# 107000 if you're going to be connecting to your sshd on the non-sta
# 108000 www.ubuntuguide.org __eou__ __eot__  we dont use that guide
# 109000 is there some samba server GUI for gnome? __eou__ there's no
# 110000 anyone here know any good psp/linux/ubuntu pages i can brows
# 111000 did you get nvidia DEBs to work alright? __eou__ __eot__ i d
# 112000 okay. sitting next to me is a rescue prompt with my new targ
# 113000 I run it on amd k7 500 __eou__ I think it's 500 __eou__ amd
# 114000 Where do I find my kernel.config (I wan t to check if I have
# 115000 How does one go abouts editing gnomes, right click menu? I w
# 116000 muine music player wont play the tracks :S __eou__ __eot__ m
# 117000 Q: what utility replace Google-desktop (the search tool) und
# 118000 Care to create a pastebin with what 'iwconfig' gives back? _
# 119000 ello!! __eou__ is it possible to transfer the root and swap
# 120000 Mount: mouting /root/dev on /dev/.static/dev failed: no such
# 121000 oh hes gone now __eou__ Ok, can anyone help me fix my dvd dr
# 122000 My "ifconfig" is only picking up a loopback interface and no
# 123000 would an athlon 64 3800+ dual core use a 686-smp kernel or a
# 124000 ok, now i have amarok 1.3.8   It does 'detect' my ipod, tech
# 125000 I wondering if I should dist-upgrade to hoary. Any comments?
# 126000  Encoding as 16 kHz  32 kbps single-ch MPEG-2 Layer III (8x)
# 127000 sound blaster 16 pnp __eou__ can ya explain that in laymans
# 128000 can anyone recommend pmud over pbbuttons? __eou__ __eot__ Su
# 129000 prolly means the dev is not ther __eou__ prolly means the de
# 130000 don't thank me yet __eou__ nfi if it works ! :o __eou__ prob
# 131000 can someone help me with the chmod command? __eou__ __eot__
# 132000 and it couldnt find it __eou__ I did, i typed in 'sudo wine
# 133000 how do i make amarok play mp3 files? i'm using gstreamer eng
# 134000 you guys, how do i check if the xdamage extension is loaded
# 135000 Anyone know how I can use .rpm files with ubuntu?  I just in
# 136000 ^-^ __eou__ raight, out of the box :) __eou__ blackbox, flux
# 137000 i have a microsoft intellimouse under ubuntu linux.  when i
# 138000 any good programs for making pictures look better?  this one
# 139000 ah... yes... tricky :9 __eou__ __eot__ yes it is, and only u
# 140000 natutilus as root?  *shudders...* __eou__ __eot__ lol what's
# 141000 I am reading xkb and xmodmap docs, I tried some xmodmap scri
# 142000 sudo ln -sf /usr/bin/Xgl /etc/X11/X <-- this does not work _
# 143000 hey __eou__ do a /nickserv info zeeble __eou__ blah. well, t
# 144000 anyone used cygwin __eou__ i ask for just general info ... _
# 145000 hey when i type mkdir /media/partitionname __eou__ it says "
# 146000 ok ill check it out __eou__ nothing else i can do then __eou
# 147000 pygtk comes bundled in ubuntu or I have to install it? __eou
# 148000 anyone knows how to configure clients for tor or privoxy __e
# 149000 ubuntu> no root password use sudo __eou__ Kadran> did you in
# 150000 dont suggest that __eou__ __eot__ Why not?  It's pretty effe
# 151000 turn the brightness down... __eou__ __eot__ it's about eight
# 152000 hello. __eou__ hello. __eou__ can someone tell me how the ip
# 153000 Hi ppl __eou__ I need to copy a file to a USB external disk
# 154000 Is there a package that provides a startup script for iptabl
# 155000 Is the live cd really really slow or is it my cd drive, and
# 156000 !tell zawa about restricted __eou__ __eot__ cyne: please tak
# 157000 No clue __eou__ i think it's fat16, though __eou__ will some
# 158000 bah i still need to configure modem, printing, mail server,
# 159000 how do i change boot loader options during install of dapper
# 160000 any idea howto get sound working on flash videos ? __eou__ d
# 161000 what is your problem? __eou__ __eot__ I cannot read from a C
# 162000 hi __eou__ please how could i get the list of kernel loaded
# 163000 SMACK! __eou__ SetUID BAD!! __eou__ __eot__ man chmod __eou_
# 164000 what would the package name for gd be? __eou__ can I search
# 165000 Hum. Looks like a bug needs to be filed against ubuntu' use
# 166000 Is there a command to see the freespace on the ubuntu filesy
# 167000 hehe, 's cool __eou__ __eot__ dr3wster, sudo /etc/init.d/apa
# 168000 yw __eou__ ( master boot record ) __eou__ __eot__ great mind
# 169000 im running foresight linux as a guest os using vmware player
# 170000 is there any way to remove a package that ubuntu-desktop dep
# 171000 I just detected an event through firestarter from kornbluth.
# 172000 does anyone know if there's a command line equivalent for sw
# 173000 what is a mythtv ? __eou__ __eot__ looks awesome __eou__ __e
# 174000 I just installed vnc4viewer __eou__ __eot__ congratulations!
# 175000 anyone know how to configure the screensaver in xubuntu? __e
# 176000 hey, Whats a good program to learn python in or any coding _
# 177000 is there anyway to make a ubuntu installation boot terminal
# 178000 has anyone here tried installing ubuntu on a G3? __eou__ __e
# 179000 For the screensavers, it has a "Pictures Folder" for an opti
# 180000 can anyone please tell me where can I download dapper cd ima
# 181000 Is there anyone here whit a ATI Radeon 9800 pro that install
# 182000 i have a symlink from hda to hdb. i'm worried that everythim
# 183000 hello, guys, please tell me what i should add to my crontab
# 184000 hi, just installed ubuntu on the laptop, happyness so far. h
# 185000 does anyone remember the name of the disk partitioner that i
# 186000 hey guys i have a problem __eou__ i just installed ubuntu ba
# 187000 hi any graphical tool to choose between GDM and KDM and to c
# 188000 Hello everyone __eou__ Im thinking of installing ubuntu on m
# 189000 hey, does any1 know where the option in the live cd install
# 190000 Still looking for someone to help me with the datadump issue
# 191000 hi guys... i was about to install kubuntu-desktop on ubuntu
# 192000 Basically, I am using a Ubuntu 6.06 CD; I always occasionall
# 193000 I'm in a fix with grub, guys __eou__ __eot__ how so ? __eou_
# 194000 Why do some companys employ C/C++ programmer under Linux, no
# 195000 rich: u dont need to find it, just type wine <windows progra
# 196000 hello all--Can anyone point me to a document on editing/crea
# 197000 http://paste.ubuntu-nl.org/24097 __eou__ __eot__ checking yo
# 198000 Keyserver timed out? __eou__ __eot__ yea you just timd out t
# 199000 I want to use a package that's available in debian non-free
# 200000 cant compiling the kernel your self possibly cause problems
# 201000 hey all, just installed Ubuntu and I'm stuck in the log-in s
# 202000 Does anyone know who owns Microsoft? __eou__ Friend (not one
# 203000 #ubuntu-xgl is dead __eou__ i cant get both cedega and beryl
# 204000 folks, do linux files have a "creation date", and if so, how
# 205000 it seems quite impossible to install wlan without having int
# 206000 does the freshnet vim work fine? __eou__ __eot__ Yes __eou__
# 207000 So I cant use the CDROM to install ubuntu and im also having
# 208000 is it possible for ubuntu to auto-detect when an external mo
# 209000 How do i execute .sh file? __eou__ __eot__ sh filename.sh __
# 210000 I'm almost positive I've installed my root filesystem to a l
# 211000 Once, I installed GVim, but I have uninstalled it. However,
# 212000 LorD-LsD I'm not sure rsync is the way to go __eou__ __eot__
# 213000 Hi, howcome /dev/fb0 is unrecognized in the default installt
# 214000 post your xorg.conf file here:     http://paste.ubuntu-nl.or
# 215000 is it worth upgrading to 6.10? __eou__ my only concern is po
# 216000 i have problems with my wireless broadcom adaptor. It's a 43
# 217000 how do i set that? __eou__ __eot__ sorry? how do you set wha
# 218000 how do i access what programs launch at start-up? __eou__ __
# 219000 I'm having problem with my soundMax sound card. I get sound,
# 220000 Hi __eou__ n00b having mp3 trouble any one want to refrain f
# 221000 perl LOL? __eou__ I'm sure python and ruby rock also, but pe
# 222000 hello everyone, I am having trouble getting Ubuntu Edgy to b
# 223000 i have a question regarding java i have installed JDK1.5 on
# 224000 how do I run scripts/text files from console? __eou__ __eot_
# 225000 I DIDN'T GET PHOTShop RUning!@ BUT I GOT IMAGEREADY WHICH IS
# 226000 woot __eou__ finally got headset work and sepreate soundcard
# 227000 How can I check how much disk space is left on my HD? __eou_
# 228000 am I correct in assuming that burning a ubuntu image onto a
# 229000 hello guys.. Is there any recovery mode, in case that my edg
# 230000 why not just install the new kernel instead of all that? :)
# 231000 I am 37/M/USA 6'2" 255 lbs brown hair blue eyes Virgo who li
# 232000 I have a USB external HDD, how do I format it and what is th
# 233000 does Wine come by default in the 6.06 CD ? __eou__ __eot__ I
# 234000 does anybody here use Ubuntu on a reasonably high-end laptop
# 235000 lol __eou__ how do that work? __eou__ __eot__ yes all over b
# 236000 hi guys __eou__ Needing some installation help with a progra
# 237000 hi every one __eou__ How to make packages for Ubuntu? __eou_
# 238000 how do i run gdebi ? __eou__ how do i run gdebi ? __eou__ __
# 239000 Hullo. May I ask a few newbee questions? __eou__ Well... I s
# 240000 the time command's operation is contradictory to it's man-pa
# 241000 can someone help me with mounting windows partion(s)  I have
# 242000 how do I recover a file I just "permanently deleted" from my
# 243000 hello __eou__ I would just use cygwin __eou__ __eot__ I have
# 244000 I need a good app for writing algebraic formulae out. Any su
# 245000 hey bman __eou__ its fox __eou__ lol __eou__ how can i find
# 246000 I have just done it willi1 __eou__ But now it is not allowin
# 247000 where could i get some themes for xmms __eou__ __eot__ http:
# 248000 oye __eou__ apt-cache search pam | less __eou__ __eot__ very
# 249000 hmm, Linksys' stuff has really seemed to have degraded ever
# 250000 I just upgraded my kernel to  2.6.17-11-generic and my wirel
# 251000 used easyubuntu to install sun-java and other stuff, acciden
# 252000 hey all. can someone tell me how to prevent my slave hard di
# 253000 Hello, world. __eou__ OK, bash/linux/sudo experts, find the
# 254000 !za __eou__ comeon... what's the terminal command to see the
# 255000 conrad_: you still here? __eou__ keller: you still here? __e
# 256000 can someone please help me setting up MultiGet download mana
# 257000 Hey guys, are there any 64 bit drivers out there for broadco
# 258000 if i set up a fat32 partition, can linux write on it? I just
# 259000 I didn't know DSL used gnome __eou__ __eot__ he was asking f
# 260000 I'm back. I still cannot install beryl-I get the unmet depen
# 261000 do I have to login as root to install stuff? I remember need
# 262000 checking for GTK - version >= 1.2.0... no        *** The gtk
# 263000 Help! When I try to blacklist my Wifi drivers using the "sud
# 264000 I accidentally closed the chat. Did someone have some soluti
# 265000 What is the command to determine which host is the DHCP serv
# 266000 it says "Totem Mplayer" and it doesnt play. __eou__ __eot__
# 267000 #ubuntu should have a web interface __eou__ __eot__ there's
# 268000 How can I partition my HDD and install Windows? __eou__ How
# 269000 NTFS-3G has really worked wonders for me, really glad with i
# 270000 hmf! where can I get this module PEAR-Crypt_CHAP ? __eou__ _
# 271000 how can I get ati sound drivers for my laptop, they're gone
# 272000 Ummm... anyone think they can help me out with getting my wi
# 273000 hello :) __eou__ i have an issue with tightvncserver :( __eo
# 274000 Amarok has a small equalizer, only 10 headers __eou__ yea am
# 275000 how to count words "word" in myfile.txt? __eou__ anyone? __e
# 276000 that said, i don't know why it wasn't like that before ;) __
# 277000 I'm gonna stab Dan __eou__ I'm gonna pull my friggin hair ou
# 278000 anyone have any ideas why,  since upgrading to feisty, my wi
# 279000 libata sucks bigtime __eou__ i can't tweak my harddrive __eo
# 280000 hello __eou__ i am having a problem with add remove __eou__
# 281000 Hi all __eou__ i have a query relating to Acer  AL1706 TFT _
# 282000 packages in edgy-backports should not have dependencies that
# 283000 Hey guys, is there a firewall default for Feisty ? __eou__ _
# 284000 does wine not work on feistyx64 __eou__ Wine Windows Emulato
# 285000 hello can someone help me im in the LIVE CD now but i cant I
# 286000 when i enter http://bigsnake_net.photo.163.com/ , firefox sa
# 287000 sigh, how can i install ATIs drivers when Ubuntu wont let me
# 288000 just apt-get remove vim-tiny and apt-get install the full ve
# 289000 hi all, is it possible to migrate from Debian Etch to Ubuntu
# 290000 I installed 7.04 on a VGN-N230E, and it works fine -- but my
# 291000 I was on youtube the last day looking for feisty and Beryl v
# 292000 according to winehq, office 2007 doesn't won't install on di
# 293000 hi! I read intel releases great graphics card drivers for th
# 294000 hi,guys i have just installed ubuntu , and i was wondering h
# 295000 Whats the command to see processes that are running on my ma
# 296000 is it recommended to keep /var/www/ owned by 'root'? cause i
# 297000 I put in the 7.04 live cd and it just scrolls "/bin/sh: Can'
# 298000 how do I get X to use a better refresh rate __eou__ it won't
# 299000 !nvu | myo (you should also be able to use the edgy package
# 300000 how do you get the installer to install w/o 'formatting' / _
# 301000 becouse it is a sudo __eou__ __eot__ wasn't the case on 2 ot
# 302000 is there a *nix command similar to 'comm' that compares two
# 303000 I need help with azureus: my torrents keep going down to 0 k
# 304000 what is a good torrent client for ubuntu....bittorrent has l
# 305000 Azureus __eou__ anyone know of a good Nintendo 64 emulator?
# 306000 how to make "ctrl"+"alt" a third-level-choser?!? __eou__ __e
# 307000 Can anyone help me transfer my outlook express information t
# 308000 help my apache is broken __eou__ __eot__ what happened? __eo
# 309000 how long is 'Installing system' supposed to take via the reg
# 310000 ergh, ubuntu installed but crashes on next system boot. __eo
# 311000 is there a console command for comparing files? __eou__ __eo
# 312000 Say, where it is possible to load a driver for HP 4400c __eo
# 313000 hey all... anyone got a fix for e1000 under x64? I get 'can'
# 314000 is there anyway to have programs start on ubuntu startup.. l
# 315000 i have the ati radeon x1400 video card in my inspiron 6400 a
# 316000 Question: I just got home from college and my parents have s
# 317000 What's the difference between an apt-get and an aptitude? __
# 318000 hey all, I'm having trouble with permissions on a new hard d
# 319000 i'm having partition problems :( __eou__ I want to dual boot
# 320000 blairellisL im sure with the advanced options you can be mor
# 321000 ok __eou__ I've got ndiswrapper installed, with its awesome
# 322000 Arg! Can anyone explain this? My Mac OS 10.4 laptop can get
# 323000 do anyone know what to do to make a bootable CD? i'm a newbi
# 324000 haha, shadowmancer, I was about to ask if you were connected
# 325000 anybody ever have eth0 and eth1 just disappear on a reboot a
# 326000 hey, I was considering trying out 7.10 tribe 3 (for some new
# 327000 hi,  is it possible to type a command in the linux console a
# 328000 how do I use aptitude or apt to show the locations of instal
# 329000 why did you PM me? __eou__ __eot__ it is a trick with the bo
# 330000 or, Win2k on one drive, and Ubuntu on the other, or somethin
# 331000 Hi all __eou__ *I've got a little... problem* (a.k.a. Glotti
# 332000 is there a doc on how to install .deb files? __eou__ actuall
# 333000 do you have any ideas how to fix this error im getting with
# 334000 you there? __eou__ __eot__ yes __eou__ __eot__ hi! I was won
# 335000 hi, I have an asus DRW-1608P, and about one week I can't bur
# 336000 can anyone guide me? i want to use my mobile phone as a mode
# 337000 hm.. i've installed ubutnu and my resolution was crapy, so i
# 338000 yay microsoft messed up my ubuntu partition __eou__ i tried
# 339000 okay i need help setting up an SSH server on Ubuntu Server F
# 340000 when i tryed a sudo apt-get update i got this error msg: W:
# 341000 any ideas where do I set the number of workpaces so cube on
# 342000 Where can i get earlier versions of Ubuntu __eou__ __eot__ w
# 343000 hello everybody! I need a specific answer... __eou__  I am t
# 344000 is there any way i can make my own start menu for ubuntu? i
# 345000 sudo aptitude download <packagename> :P __eou__ __eot__ why
# 346000 if i want Tomboy Notes to autostart on boot up, is it just a
# 347000 his RDM reports that he doesnt need, prob cuz the restricted
# 348000 hi, i just installed eterm via a sudo apt-get install eterm
# 349000 Any C programmers out there? __eou__ I'm just starting to us
# 350000 hey anyone know how to kill compiz from the terminal? __eou_
# 351000 Morning, all.  I'm trying to install 7.10 on my laptop.  All
# 352000 howdy folk __eou__ does anyone know how to get the shell eff
# 353000 i just installed ubuntu 7.10 and enabled gl desktop. what do
# 354000 For importing windows settings, do you have to reformat the
# 355000 for some reason proprietary drivers don't want to install fo
# 356000 Is the defualt shell in gusty still dash? __eou__ does anyon
# 357000 hi, i accidentally converted my ntfs win partition to ext3.
# 358000 anyone got patches for kernel 2.6.23 for the new ati drivers
# 359000 how do i get my card reader to work? dmesg tells me it just
# 360000 oh jesus __eou__ I f*cked up my laptop... :( __eou__ I bette
# 361000 I've deleted the windows partition and now grub wont boot ub
# 362000 no xstat __eou__ src? run php without apache???? __eou__ __e
# 363000 is there a command to pull all the .mp3 files out of seperat
# 364000 I haven't had to update my system in 2 weeks.. is this norma
# 365000 KILL DASH NINE __eou__ __eot__ are you singing the song? __e
# 366000 hi. i'm trying to emulate N64 games with mupen64 and kamefu
# 367000 can anybody help me in changing the desktop icon text color
# 368000 Chill firefox and thats abou tit __eou__ __eot__ null needs
# 369000 i just copied over a directory from a seperate partition to
# 370000 seriously, can anyone aid me in getting airport-config worki
# 371000 hi everyone, __eou__ anybody with freezing issue on Gutsy ?
# 372000 how do I give a bridge interface a gateway address? __eou__
# 373000 i can't load my xserver __eou__ and i have one important fil
# 374000 help, how come after uninstalling wine .. and removing the .
# 375000 is there a way to kill X only without affecting all the serv
# 376000 Hello everyone. I recently installed ubuntu-desktop over a k
# 377000 archive.canonical.com/"dist name" __eou__ __eot__ much appri
# 378000 does ubuntu have a link that explains the size of partitions
# 379000 are there any admins for this place? __eou__ __eot__ Yes, th
# 380000 Is there a way to del selective files recusive, ie i want to
# 381000 Ok, here's a question. I have a box running U 7.04 server. s
# 382000 how would i go about  substituting a library (libgpod) from
# 383000 hello. the process "ksoftirqd" is consuming between 20-25% o
# 384000 http://amarok.kde.org/wiki/Media_Device:IPod endo_ also stuf
# 385000 hey guys - i am installing xubuntu as i have an OLD computer
# 386000 I want to reset all the desktop configuration for a user to
# 387000 can someone recommend free software for managing a open sour
# 388000 I have an issue with system time between ubuntu & windows xp
# 389000 ho __eou__ hi __eou__ how can I install kernel sources with
# 390000 hi, I have java installed but I cannot seem to get it runnin
# 391000 how can i burn an iso to a cd/dvd? __eou__ __eot__ Right cli
# 392000 is there a way to recursively load all the files in a direct
# 393000 !ohmy | xen_ __eou__ !pastebin | EtherNomad __eou__ __eot__
# 394000 Hello Ubuntu guys I need some help on my installation of ubu
# 395000  no __eou__ whats up? __eou__ so the sound worked b4 updates
# 396000 I'm trying to install 7.04 on an hp laptop with an ati card
# 397000  There is no entry for rar in the man pages on my terminal.
# 398000 hi, I have about 200 files in a Directory, file name is cbq-
# 399000 I'm still having a problem getting Ubuntu to set my monitor
# 400000 _Oz_-> ummm damn small linux works with 50meg hd and 64meg o
# 401000 pelo: should i go manual network config? __eou__ instead of
# 402000 hi chaps. __eou__ I'm dying here. __eou__ I've been trying t
# 403000 what is the difference between linux x86 and linux-64 __eou_
# 404000 make sure you install the smbclient package too ! __eou__ __
# 405000 So, I recently installed ubuntu on a thinkpad x60, and the w
# 406000 anyone having problems with azereus on amd64? __eou__ __eot_
# 407000 hey guys, ty for the help I have studio working just fine no
# 408000 When ever I try to enable windows effects, I get a message t
# 409000 so it doesn't work and you claim it does? great logic! __eou
# 410000 anyone know why video would be choppy even though compiz and
# 411000 lilo = linux loader __eou__ !ask | mohammed __eou__ lazy: ta
# 412000 i even compiled the latest alsa __eou__ __eot__ did you try
# 413000 whats wrong with pidgin ? __eou__ __eot__ nothing is wrong w
# 414000 thanks linxeh __eou__ i was just wondering what programe to
# 415000 hmm... I've been messing around a bit with my suspend resume
# 416000 hi all how can i run things at startup? __eou__ __eot__ you
# 417000 hello guys. i have ubuntu 5.04 installed, is it possible to
# 418000 that we definitely have. __eou__ __eot__ do you know iptable
# 419000 can anyone refer me any compiler for compiling the prolog pr
# 420000 what is squid __eou__ can i limit total bandwidth /s  combin
# 421000 does anyone here use xchat? __eou__ __eot__ i am..right now.
# 422000 !offtopic | gogeta __eou__ __eot__ this is a support issue _
# 423000 Felonius - If you only format the Ubuntu partitions and don'
# 424000 thinking about ubuntu for my hand-me-down macbookpro; open t
# 425000 What program can I use to convert .ogg files in .wav? __eou_
# 426000 so i have two physical disks in LVM, in one volume group and
# 427000 can anyone help me with my problem? don't mean to seem impat
# 428000 i know it wouldn't really matter, but does anyone know a bet
# 429000 : What? __eou__ They all 'act up' __eou__ __eot__ One fine d
# 430000 is synaptic not downloading because of the high use of the s
# 431000 Ah, the joy of downloading. __eou__ it's like watching paint
# 432000 can someone please give me a hand, i've been having an issue
# 433000 anysuggestions? __eou__ __eot__ you are sure that you dont h
# 434000 when i wanna install ubuntu i get an IO error __eou__ :| __e
# 435000 who uses torrents? __eou__ Hischild: Private chat? __eou__ y
# 436000 third tab over __eou__ __eot__ still same problem __eou__ __
# 437000 is there a 'absolute beginner' room for a question? __eou__
# 438000 any one know why i can only get a 16 kb dl rate...? usually
# 439000 I have that problem! __eou__ __eot__  have you found a fix y
# 440000 what is the new bittorrent client in ubuntu called? __eou__
# 441000 Camorama only grabs pics __eou__ i also used gstreamer-prope
# 442000 WIth the new SSL vulnerability, what can I do to patch my sy
# 443000 is there a way to download ubuntu mobile ? __eou__ __eot__ h
# 444000 install either libstdc++-dev or libstdc++6-dev and you shoul
# 445000 How do I set the logical name of a network card? My wlan0 di
# 446000 alextvm :  sudo mount -t ext3 /dev/sda6 /mnt/root __eou__ su
# 447000 hi __eou__ I can't mount my windows drive. it says "$logfile
# 448000 q. how can i disable the automatic update everyday or so ? _
# 449000 Hi, sometimes when I login (like this time), my desktop does
# 450000 I am trying to run  sudo alien -i lightscribe-1.8.15.1-linux
# 451000 Hello. I am trying to change the Network card MAC address, I
# 452000 I'm currently running 7.04.  I have the 8.04 CD from Canonic
# 453000 can anyone suggest a good gmail notifier app for ubuntu?  so
# 454000 I guess no one knows the answer to my questions? __eou__ My
# 455000 Hi, I got the 'application/places/systems' bar at the bottom
# 456000 How can i create images of cd's in ubuntu, like .iso files?
# 457000 I've never had a problem with Envy, but if its giving you pr
# 458000 I am using the ATI proprietary drivers and whenever my scree
# 459000 how do you list the users in a terminal? __eou__ __eot__ w _
# 460000 have youchecked  system>preferences>preferred applications?
# 461000 Hi folks __eou__ What I've been used to using is a combined
# 462000 Hi, Im interested in testing a beta driver from nvidia, but
# 463000 hi all, i get a "frame sync error" when trying to open an .a
# 464000 hey folks I installed imagemagick package but i dont see any
# 465000 guys, i got a lil problem. Ubuntu doesnt start the cron daem
# 466000 i found out that whenever i open firefox things get really s
# 467000 hey guys __eou__ I've got a problem with my graphics card __
# 468000 pgrempton:  are you trying to use the nv or the binary nvidi
# 469000 Anybody know what the apt etc. equivelant is for the command
# 470000 Is there a free weblog application for linux?  Basically I w
# 471000 Is there a way to change ONLY the Application menu icon? __e
# 472000 lol, why do you use ubuntu at work ? __eou__ __eot__ Why not
# 473000 #ubuntu-offtopic would be a start __eou__ __eot__ thank you!
# 474000 so is wicd every going to work in hardy or am I stuck with t
# 475000 nobody who can help me with Grub Error 15: file not found? =
# 476000 did anyone here type this command: sudo hdparm -B 254 /dev/s
# 477000 how do I get the compiz cube setup in ubuntu 8.04 default in
# 478000 it plays fine for me __eou__ __eot__ here says 'no video' an
# 479000 Hi! Can someone please tell me, what it takes to add a packa
# 480000 hi, i have some private data and files and i would like to p
# 481000 Does anyone know how to migrate my mail from kmail into a co
# 482000 !away | TheMaxzilla __eou__ !ops | TheMaxzilla away messages
# 483000 is it possible to make pidgin to show some kind of popup whe
# 484000 I often get notices that updates are available for software
# 485000 ok, gnash doesn't seem to do anything at all. no gootube, no
# 486000 echo $(( ($(date -d 'Mar  1 2009' +%s) - $(date +%s))/60/60/
# 487000 man adduser says useradd might be friendlier __eou__ __eot__
# 488000 pici: no email in my box __eou__ why does #python require us
# 489000 can I back up my laptop's entire drive?  I'm talking multi-p
# 490000 hello all __eou__ where can I find new vlc for ubuntu ? __eo
# 491000 I am sorry, I still don't understand this RESOURCES_64BIT op
# 492000 how can I login with root account? Do I have to activate it?
# 493000 anybody : how much of memory should i have on hdd to have ub
# 494000 can someone help me to get a python-script start with xdm? i
# 495000 any photographers here? __eou__ any photographers here? __eo
# 496000 can someone help me on remounting my secondary hard drive?
# 497000 anybody know how to fix CRC Error? __eou__ __eot__ in what c
# 498000 hey friends!what does make modules_install do after make the
# 499000 is anyone able to watch videos on nbc.com? __eou__ __eot__ t
# 500000 When editing the permissions of a directory, do i need to en
# 501000 Can anybody please suggest the best format to record a DVD f
# 502000 Hey i am having a problem with resolution, I believe the sou
# 503000 Just want to confirm if I want to compile a C++ sour code wi
# 504000 samba has no content encryption __eou__ __eot__ wouldn't tha
# 505000 i have a proprietary nvidia driver and my pc runs on a gefor
# 506000 Everytime I use gnome network manager and I use an encrypted
# 507000 What is the command line for finding out what process is usi
# 508000 Most flash sites dont even work on my wii any more. :( they
# 509000 did i mention that my dapper->hardy upgrade left me without
# 510000 Hey i have a question __eou__ is there such a thing as an ub
# 511000 EMERALD - how do I make one? __eou__ :-$ __eou__ __eot__ htt
# 512000 can someone help me with the ubuntu 8.04 server edition inst
# 513000 hello guys.. im about to use distro upgrade thingy to upgrad
# 514000 HEY OH MAN i cant start the trendmicro housecall virus scann
# 515000 I wish some of the distros would add VMware to their package
# 516000 anyone know if X11 uses xorg.conf like it use to?? im trying
# 517000 will installing an xp virtual box make me vulnerable to the
# 518000 why I can't configure more than 2 desktops?  if I up the amo
# 519000 1318 people ignore my pleas.... __eou__ __eot__ it happens..
# 520000 hello __eou__ Could someone by any chance walk me through up
# 521000 man that time flew by, seems like just yesterday I was insta
# 522000 i can't get firefox to launch from the applications menu --
# 523000 What's the terminal command to list all running processes wi
# 524000 hiya, ive just got a headset but im having trouble getting t
# 525000 Can someone tell me how to install a program through termina
# 526000 but wine is only able to run one executable, not an entire g
# 527000 can someone help me with the command line please, i want to
# 528000 After the installation, is it real that I have to update my
# 529000 Hey, my resolution is messed up after upgrading to a Widescr
# 530000 where's a good place to put shared files? __eou__ files that
# 531000 hi, I recently installed Ubuntu 8.10 and I have a problem: i
# 532000 Hey all! __eou__ Is there a Apple or Mac channel? __eou__ __
# 533000 once i get Ubuntu exactly the way i want it is there a way t
# 534000 yes, I did it once as an exercise; /usr/share/doc/wpasupplic
# 535000 I seem to get a corrupted X session at random on occasion. I
# 536000 how do you check for updates in synaptic package manager on
# 537000 hi, why is totem the default dvd player when it can't play d
# 538000 How do I install a .deb via command line, and how do I make
# 539000 Does anyone here have excel 2007 and is willing to make me s
# 540000 whats pruning? __eou__ __eot__ removing useless stuff from a
# 541000 someone know in what reposiroty is ntfsprogs? __eou__ __eot_
# 542000 No-one has an idea for my problem? __eou__ I've just a quest
# 543000 I am going to buy a dell xps m1530 today if I can. do people
# 544000 does anyone know of a firefox 3.1 package for amd64? __eou__
# 545000 Somebody knows about a nice black theme for ubuntu 8.10? __e
# 546000 hey all, I'm looking to make the shell that comes with Ubunt
# 547000 I have 810 64bit installed on a SATA disk .... is it better
# 548000 Anyone: whats the best multiplayer game on linux right now??
# 549000 I have a folder in my Trash and apparently I don't have the
# 550000 There's a cisco compatible vpn client in the repositories ..
# 551000 hi __eou__ i'm trying to install the latest eclipse, but the
# 552000 I see __eou__ I want it to print out the package description
# 553000 has anyone successfully setup and got working a fingerprint
# 554000 if i got the ubuntu repo would that include intel386 and amd
# 555000 rsync would fail - obviously. data wouldn't get written anyw
# 556000 mpegtranscode __eou__ __eot__ will mpegtranscode burn the dv
# 557000 so you need port forwarding / DNAT? __eou__ __eot__ I don't
# 558000 I'm finding Ubuntu as easy to use as Windows XP unless I fee
# 559000 how can i adjust ubuntu to only have one desktop?  (the defa
# 560000 Anyone here familiar with RAID setups. Have a problem with s
# 561000 Ah, neat, ubuntu now has a USB flash drive installer tool. _
# 562000 Guys, could you check this over and tell me how it looks?
# 563000 hi Mez __eou__ make sure you install samba first HawkLion __
# 564000 @ Tesla Also Running Ubuntu on an EEE PC. __eou__ @ Tesla I
# 565000 I'm having trouble with suspend/resume in Hardy.  I've upgra
# 566000 Doesn't someone know how to make a shell script with an infi
# 567000 :) __eou__ the server commodore running apt-mirror, it's up
# 568000 DIAF __eou__ its only rude if they listen in the first palce
# 569000 Does anyone have any idea about my problem? :P __eou__ __eot
# 570000 how to get blender working? __eou__ I got blender installed
# 571000 ugh fucking compiz is ultra-broken right now __eou__ Oh, sor
# 572000 think they had the same problem with 8.10 __eou__ __eot__ Th
# 573000 in shell, how do i clear my file history? __eou__ __eot__ fi
# 574000 you from slartibartfast? __eou__ __eot__ yes __eou__ __eot__
# 575000 Currently running ubuntu from usb stick. Unfortunately progr
# 576000 Can Ubuntu read UFS? FreeBSD's filesystem? __eou__ __eot__ y
# 577000 where can I get a version of wine that is greater than 1.0.1
# 578000 laptop DDR2 is 200pin __eou__ __eot__ thanks. It's a desktop
# 579000 hi, can anyone please explain to me how to effectively forma
# 580000 Is there any SSH guru out there who can explain what the err
# 581000 help! trying to install vmware 2.0.1 on ubuntu 9.04 64bit, s
# 582000 no recommendations? __eou__ for a tv tunner card __eou__ __e
# 583000 anybody that's good with cron have a moment to help me troub
# 584000 !clone > dadrock __eou__ __eot__ what kind of program is gks
# 585000 Tyranos, I have a x1600 myself __eou__ Tyranos, the drivers
# 586000 nope... didn't work, how do i force the OS to release contro
# 587000 is there a specific iso for linux netbooks? __eou__ er .. ne
# 588000 Linux 2.6.29.4 i686 GNU/Linux __eou__ __eot__ same, but with
# 589000 If you are using vmware, have you checked out:  http://linho
# 590000 indus:ok __eou__ __eot__ : why don't you check backtrack web
# 591000 i just upgraded from 8.04 to 8.10 and all windows have lost
# 592000 please how could I fiix this: Authentication failed when i t
# 593000 can i remove pidgin and leave finch? or if i remove pigdin t
# 594000 does google labs from gmail work with ubuntu? __eou__ __eot_
# 595000 !ekiga | krishmish __eou__ __eot__ but will i be able to con
# 596000 while using my ubuntu i felt the need for some a desktop wid
# 597000 i don't even recognize linux anymore when i'm fiddling with
# 598000 python $file_name_you_want_to_run __eou__ __eot__ it says" p
# 599000 hi, how to install ubuntu desktop, and uninstall xubuntu des
# 600000 is there an easy way, tool or utility, that can help me view
# 601000 how can i change my updatemanager to look for development re
# 602000 anyone know how to access mac user files on ubuntu? __eou__
# 603000 !ot |  joel_ __eou__ __eot__ ubuntu can be difficult it depe
# 604000 the ftp command returns error 500 Illegal port command __eou
# 605000 hey, my WLAN is not work, but the light is ON , here's the i
# 606000 re __eou__ any news xorg problem with ati old card and fglrx
# 607000 how do i create usb bootable drive from server (i386) iso? _
# 608000 anyone can help me with >>> this problem rndc: connect faile
# 609000 So which should I install, 32-bit or 64-bit? I've got a quad
# 610000 I thought the wine website had links to all old versions __e
# 611000 Can I remote start a laptop running ubuntu? __eou__ __eot__
# 612000 neone have aspire one with them __eou__ aspire one __eou__ _
# 613000 how do i get usb working in virtualbox? in ubuntu 9.04 __eou
# 614000 If any one can help me that would be rad, I'm even will to t
# 615000 any opinion ,thanks but it's urgent __eou__ __eot__ i don't
# 616000 nice call ejv __eou__ __eot__ heheh, you in the market? :p _
# 617000 anyone aware of a 2.6.x live usb that is less than 60MB? __e
# 618000 I found this forum posting, http://ubuntuforums.org/archive/
# 619000 a lot of people use glade.. you might want some other packag
# 620000 can anyone help me with compiling programs that use qt? it l
# 621000 is there anyway to save the video in http://www.omroepflevol
# 622000 All the pages I am finding refer to creating your own USB im
# 623000 is there any way to read *.chm files __eou__ __eot__ chmsee
# 624000 Good evening. I'm looking for the most user friendly version
# 625000 How do I connect to a network share in Ubuntu? __eou__ How d
# 626000 hi all. whens 9.10 coming out? __eou__ __eot__ October 29th
# 627000 =\ __eou__ I get the same error using VNC viewer (offical vi
# 628000 hey guys , is there extensions for chromium? __eou__ __eot__
# 629000 So I have python2.6 and scons both installed via package man
# 630000 has anyone here bought a computer from system76?   I need to
# 631000 I got a question for Evolution E-Mail Client... How do you m
# 632000 found a petition to get shockwave on linux: http://tinyurl.c
# 633000 i cant make my ftp server work __eou__ been trying to get it
# 634000 any way to make the remote desktop active prior to login? __
# 635000 uhm, can anyone tell me how i can set a python script as my
# 636000 what are you trying to change the permissions of?  sometimes
# 637000 or mplayer __eou__ __eot__ i just hate mplayer with a passio
# 638000 got any problem with sun jdk and koala? __eou__ __eot__ why
# 639000 hi everyone, so how is karmic? __eou__ __eot__ bit unfriendl
# 640000 hello __eou__ I've just updated my jaunty to karmic just now
# 641000 MaT , you have compiz effects enabled ? __eou__ __eot__ yes,
# 642000 what is with with this new release and the nvidia cards __eo
# 643000 i have courier-imap and sendmail running... and squirrelmail
# 644000 my sound system isn;'t working can anyone help> __eou__ it h
# 645000 hi all - I'm trying to ssh to a remote server, which is lock
# 646000 hey guys. i had an issue with installing ubuntu when it firs
# 647000 Hey guys, my system crashed and the mp4 player, the instant
# 648000 could anyone access win7 shared folders from karmic yet ? it
# 649000 !it | luis_ __eou__ __eot__ i think that was portuguese __eo
# 650000 ok I installed, ubuntu netbook remix on the second drive of
# 651000 Which version of Ubuntu are you using? __eou__ __eot__ 9.10
# 652000 Hey guys Im about to wipe 9.10 for the more reliable 8.04.3
# 653000 I have a RAID1 array and tested the redundancy by removing o
# 654000 i have an easy question, i have instaled karmic on my laptop
# 655000 how do I change file associations?  I've tried changing the
# 656000 i have a new install of karmic. it comes with grub http://pa
# 657000 is there a text based web browser with javascript ability __
# 658000 Hello, can someone please help before I kill my self. All I
# 659000 I need HELP PLEASE :O RESET COMPIZ settings =( .... I alread
# 660000 Hello, I don't find flahs very stable using an 64bits oppera
# 661000 douglasawh-work: you could check the grub2 wiki page, i'm no
# 662000 anyone having problem with software enter in 64bit?? __eou__
# 663000 hi, I am trying to use the mail program to send e-mails to m
# 664000 hello i need some help, for some reason my wireless card is
# 665000  Sabre-night:  it's a problem of Window XP i think, not of U
# 666000 I dl'd a avi file, but when i play it, I can see the start w
# 667000 hmmm.. __eou__ __eot__ http://tinyurl.com/2l4vlx __eou__ __e
# 668000 lol, I come to ask a question, I don't get it answered, but
# 669000 Anyone can help with touchscreen? __eou__ __eot__ did you ru
# 670000 did you install inside Windows? __eou__ does your machine wo
# 671000 is there a way to encrypt a home partition __eou__ i mean a
# 672000 yup ive installed XP first, only thing is XP got screwed up.
# 673000 does anyone know how do i kill apt-get? __eou__ __eot__ why
# 674000 question about keyboard.  on win 7 or vista my num lock stay
# 675000 you see on  rTorrent 0.8.6/0.12.6 i want to execute a comman
# 676000  ~/.local/share/rhythmbox/rhythmdb.xml might be what you are
# 677000 hello all. i just tried to format a new hard drive. i tried
# 678000 Hi, is there any way to get more virtual desktops in 9.10? I
# 679000 very stylish to f.ck up the system __eou__ __eot__ how come
# 680000 have a system running 9.1, altho hostapd is configed to star
# 681000 Linux is for dumb mentally retarded bitches who ate too many
# 682000 no sound in karmic... I only get sound in tvtime and nothing
# 683000 DD? __eou__ __eot__ yep __eou__ __eot__
#
# 684000 is there a version of ubuntu for homosexuals and lesbians? _
# 685000 how much swap would be optimal for a netbook with 1 GB RAM?
# 686000 how to install global equalizer on ubuntu??? __eou__ how to
# 687000 that tomato is great ! __eou__ __eot__ agreed, much better t
# 688000 is there some kind of plugin to allow me to view quicktime v
# 689000 can you still use unetbootin if you don't have ANY OS on you
# 690000 Would anyone be able to recommend a good virtual ISO tool fo
# 691000 I always used samba to access windows network shares, how el
# 692000 so what if the Eskimos have 200 words for snow ?! how many m
# 693000 guys, can anyone help me, sort this out. Im helping a friend
# 694000 Can anyone tip me on annother more user friendly program tha
# 695000 I will give someone a high five if they can tell me how to t
# 696000 hey, commands scheduled via "at" aren't working.. any help?
# 697000 on grub press e __eou__ __eot__ And add the params to the en
# 698000 I have an iso for installing ubuntu. I want to install it on
# 699000 anyone know a good windows password recovery tool? __eou__ _
# 700000 ummh, I just installed Ubuntu 10.04 Beta 2 __eou__ after ins
# 701000 what command will give me the default gateway ip? __eou__ __
# 702000 when it was released __eou__ why do they make new release ve
# 703000 how do i get my box to allow me to install linux-restricted-
# 704000 Where can I get a torrent file for the 32-bit server edition
# 705000 Hi.  Just updated to 10.04, and I've noticed that all apps i
# 706000 Anyone have experence with the mx5000tools? When i perform a
# 707000 No Reflex: there is a delay after the grub screen disappears
# ...
# 2724000 i read that from here: http://ubuntuforums.org/showthread.ph
# 2725000 lsmod |grep pcspkr  what do you get __eou__ well the pc spkr
# 2726000 as in when i do a mouse drag, it opens another pdf window __
# 2727000 same here __eou__
#
# 2728000 doesn't matter. same thing happens with both files and folde
# 2729000 the package in synaptic says it's not supported by Canonical
# 2730000 check the wiki __eou__
#
# 2731000 yeah, I guess __eou__ different result __eou__
#
# 2732000  What was http://pastebin.ubuntu.com/181707/ __eou__
#
# 2733000 Thanks :) __eou__
#
# 2734000  thank you for your help, i am very excited now __eou__  Tha
# 2735000 , i need send parameters ... for example in bash i can send
# 2736000 de nada ;] __eou__
#
# 2737000 who you talking to? plz use the nick in your replies __eou__
# 2738000 ok in backport. I will take a look at backport __eou__ shoul
# 2739000 virtual machine in that case only to get the feel for Ubuntu
# 2740000 my mistake mneptok is correct next proposed lts is 10.4 sorr
# 2741000 agreed done __eou__
#
# 2742000 thanks i m gonna read and i wont install all the application
# 2743000 oh ok __eou__
#
# 2744000 pxe? thanks! __eou__ got a look at pxe installation .... it
# 2745000 thats not a user name, thats a key pairing. i don't think it
# 2746000 so you can copy paste in man, and then delete the ones you d
# 2747000 I thought it was... but gparted is the only gui tool I am aw
# 2748000 Ah, then that's not "general programming purposes" :-). __eo
# 2749000 Sorry, no - that's all I use __eou__
# 2750000 only resolution cose different way it is not workin __eou__
#
# 2751000 happens,i have suspend hibernate going misssing sometimes __
# 2752000 k...will do __eou__
#
# 2753000 you may have it installed already. i do, but i don't recall
# 2754000 the XP install disk says I have no hard drive __eou__
#
# 2755000 No, nothing will explode __eou__
#
# 2756000 so i must have a problem, right now it does ~ 9Mo/s __eou__
#
# 2757000 You mean the first disk? __eou__
#
# 2758000 hum, i may need to do a bit more research on Win4Lin than __
# 2759000 btw, how did your sudo password stop working? __eou__ you co
# 2760000 I don't know the difference between pkill and killall, meh _
# 2761000 no problem :) __eou__
#
# 2762000 i'm afraid i'm not familiar with that error... maybe google
# 2763000 ok, thanks, i'll give it another shot then :) __eou__ ah coo
# 2764000 how do you kill it? it locks up my entire system and when pl
# 2765000 thanks anyways __eou__
#
# 2766000 unetbootin is the repos for karmic, you may wish to try usb-
# 2767000 wuts the command to import those? Or should I just use phpMy
# 2768000 you really don't need that stuff for Ubuntu __eou__
#
# 2769000 programming, and office work __eou__
#
# 2770000 on average how many years do i expect? __eou__
#
# 2771000 What is PCM set at? __eou__
#
# 2772000 rather then changing in every app separately, I would use xm
# 2773000 or does one need Ubuntu for it to work? __eou__ Now I have 9
# 2774000 http://ubuntuforums.org/showthread.php?t=56949 is one way bu
# 2775000 yea, what you're saynig is removing sda5 the right way, usin
# 2776000 fair enough, though if it's from a mainline repo (and often
# 2777000 I don't play that game but TF2 and WOW run fine in it. __eou
# 2778000 nvidia __eou__
#
# 2779000 very well then. Good luck to you. __eou__
#
# 2780000 webcam is supported , just need help fixing it mate __eou__
#
# 2781000 no, never heard of it. __eou__ I love OpenOffice, but I am h
# 2782000 whateva... his los __eou__
#
# 2783000 Yes hibernate is suposed to shut down the system .. it dump
# 2784000 Idk. I've got sans obviously, it just doesn't look as nice i
# 2785000 xubuntu is light, yo ujsut have to desactivate gnome and kde
# 2786000 did it work? __eou__
#
# 2787000 want me to show u my monitor or are u searching the support
# 2788000 normal releases should show an upgrade to 9.10. __eou__ alth
# 2789000 thats why yesterday i was switching to admin account __eou__
# 2790000 seriosly you will be cracked wihin a day __eou__
#
# 2791000 -_- ive tried that before with other laps and it wasnt, i ne
# 2792000 , that didnt work neither.. __eou__ I think im going to have
# 2793000 make a binary image of it with dd __eou__ dd if=/dev/usb of=
# 2794000 I kinda like the minimalist design  but I also love the evil
# 2795000 ok, try as chelz said, right-click an .exe and go to propert
# 2796000 okay. havent read much about KVM but than its okay __eou__
#
# 2797000  sudo vi /etc/X11/xorg.conf << send any section named nvidia
# 2798000 : if ubuntu continues to concentrate it on the x , i w'll ab
# 2799000 no i am building from a .tgz __eou__
#
# 2800000 Oh, I see!  So if I wanted them installed, I'd say "apt-get
# 2801000 lucky you :( __eou__ now why won't my nvidia settings stay,
# 2802000 sorry... I can't find the tools name. __eou__
#
# 2803000 welcome __eou__
#
# 2804000 that's not normal right? usually you have to do a bunch of t
# 2805000 (don't go looking for it on dell site - they'll charge you $
# 2806000 pastebin your /etc/fstab __eou__
#
# 2807000 good call. How would i know if its the PSU? __eou__
#
# 2808000 thanks it's what a was looking for __eou__
#
# 2809000 no __eou__
#
# 2810000 its in /etc/sudoers, but you can use 'sudo visudo' adding th
# 2811000 then i will mount it ti /media/ and then put a symlink to ~/
# 2812000 ok i will deactivate it and see what happens __eou__
#
# 2813000 its just 50% now ,should i wait or kill. __eou__
#
# 2814000 sebsebseb : well, my internal speakers work fine __eou__
#
# 2815000 gotta get my laundry, be back in like 5.  id like to help yo
# 2816000 i have update-notifier running the background already. __eou
# 2817000 debian is offtopic here, this is ubuntu support only __eou__
# 2818000 ah __eou__
#
# 2819000 I believe "sudo update-alternatives --config default.plymout
# 2820000 alsamixer or anything else is already at 100%, i would like
# 2821000 tru but if you include in your command to run as a different
# 2822000 I didn't see those, do appologize for the short answer. __eo
# 2823000 my /etc/environment just has a path and that's it. __eou__
#
# 2824000 no problem. (^_^) __eou__
#
# 2825000 links? never heard of it :P __eou__
#
# 2826000 most likely if its even possible __eou__
#
# 2827000 Woot! Yep that was it. __eou__
#
# 2828000 I know its fine sorry about that __eou__
#
# 2829000 just one at a time __eou__ i have comcast so bandwidth on my
# 2830000 What are you trying to do? __eou__
#
# 2831000 thanks __eou__
#
# 2832000 right, no have not seen one yet __eou__
#
# 2833000 you might want to check this: http://bugs.debian.org/cgi-bin
# 2834000 it should be prompting you for updates up by the clock __eou
# 2835000 line 22- 27 Jordan_UI __eou__ - the I lol __eou__
#
# 2836000 How are you sharing? __eou__
#
# 2837000 no need to reinstall. just run the command and then launch t
# 2838000 why var? __eou__
#
# 2839000 To re-enter play after being killed. __eou__ lol ... like in
# 2840000 No error messages at all? :( __eou__
#
# 2841000 yast also allows you to start, stop and configure services f
# 2842000 bummer __eou__
#
# 2843000  or... something else __eou__ murchadh  sweet, i'll give it
# 2844000 yes I know but nothing happens when I click on it. __eou__
#
# 2845000 yep __eou__ what now? :o how can i make it work instead of m
# 2846000 194hrs?  thats crazy... __eou__
#
# 2847000 if you need something a bit more substantial you can use Ard
# 2848000 that searchs the package list __eou__
#
# 2849000 is it mounted "ro" ? __eou__
#
# 2850000 at one place it has to be transported into the gsm net and o
# 2851000 Done __eou__
#
# 2852000 the partitions mounts fine, it's a directory inside of it th
# 2853000 idk, have you ever had it working on any other OS? __eou__
#
# 2854000 but anything i drag there, is cut off and im only seeing par
# 2855000 it's probably ok as long as gnome-look is only providing the
# 2856000  http://www.supergrubdisk.org    There is a SuperGrub free r
# 2857000 I have been using minefield for a while and surely it's more
# 2858000 check the share settings.... __eou__
#
# 2859000 also, use the p switch when creating tar. i'll be around for
# 2860000 does it work ? __eou__
#
# 2861000 What broadcom chipset do you have? __eou__
#
# 2862000 its a server __eou__
#
# 2863000 have you tried reinstalling GDM ? __eou__
#
# 2864000 i thought you said there isn't any benefits to it __eou__
#
# 2865000 "md5sum ./file.iso" is the syntax you're using, correct? __e
# 2866000 yes, I know about that, but it's too fast __eou__
#
# 2867000 Yeah I tried that, thanks for the suggestion though. I've ev
# 2868000 ummm...okay. is that a bad thing? I have never had sound sin
# 2869000 to look cool? __eou__
#
# 2870000 :) __eou__
#
# 2871000 you don't even get grub? __eou__ can you mash tab or whateve
# 2872000 then stick with it __eou__
#
# 2873000 it's a shared drive, just a folder with files. __eou__
#
# 2874000 Oh okay. Well, don't have a clue, then. Except that I'm on a
# 2875000 And they said nothing? __eou__
#
# 2876000 where are you looking for an icon ? __eou__ it is in there,
# 2877000 how can i've sucessfullly installed my Geforce FX 5500.RUN _
# 2878000 system is uptodate,  version 2.2.0.35-0lucid1 __eou__ do you
# 2879000 sr0 is the cdrom drive __eou__
#
# 2880000 I think I'll prefer to say it's matter of taste then __eou__
# 2881000 no __eou__ depends actually __eou__
#
# 2882000 well they have different mount names one is /media/Server2
# 2883000 what movie player are you using on ubuntu? __eou__ i mean it
# 2884000 Googling "PM" but not getting a clear answer. Is that a abbr
# 2885000 it's because I didn't install it, only tried it from USB and
# 2886000 I'm sure it has, but if I want lightweight I usually go with
# 2887000 either in ~ or in /var/spool/mail or similar. depends on you
# 2888000 yeah I hate printing, especially in ubuntu it is even worse
# 2889000 i'm not sure... :( __eou__
#
# 2890000 Thanks, it installed them now. I'll test it on the windows b
# 2891000 #ubuntu-offtopic __eou__
#
# 2892000 : thank you but i can not get the bittorent download for 10.
# 2893000 It's capital O, the site doesn't load at all, so it looks pr
# 2894000 sudo: can't open /etc/sudoers: permission denied    newline
# 2895000 I'm afraid I've never set up a multiple port nic card before
# 2896000 but will it work with the new hardware? __eou__
#
# 2897000 Almost every command in Linux, but some manpages are not rea
# 2898000 Not done ICS in years either. :) my router handles it all. _
# 2899000 thanks __eou__
#
# 2900000 one is packages/built/designed to be used with ubuntu (menu
# 2901000 not exactly what I am doing, but that might be a good start.
# 2902000 I was hacked by Anon thats why I want it __eou__
#
# 2903000 Yes there is a chance for data loss. You should always backu
# 2904000 intel Q965 __eou__ its was working right with my hp 19" moni
# 2905000 ok good then choose something and pick your partitions __eou
# 2906000 i would like to honestly say that I exhausted all options tr
# 2907000 i can't really search (i'm not on ubuntu) __eou__
#
# 2908000 it does the job and has a built in crossfade option that I l
# 2909000 Thhat doesn't look like it. try lspci | grep WLAN __eou__
#
# 2910000 hm, not USB or anything then, very odd __eou__
#
# 2911000 i'm sorry, i don't think I'm going to be able to help you. _
# 2912000 That would only allow one session wouldnt it? __eou__ I have
# 2913000 netherlands, europe __eou__
#
# 2914000 install the dev package of it __eou__
#
# 2915000 because its not official and it doesn't do package upgrading
# 2916000 haven't had very serious problems, some annoying ones, but n
# 2917000 yes __eou__
#
# 2918000 whats a cool one to check out? __eou__
#
# 2919000 Do you mean install completely without network support? I re
# 2920000 i've made all my problems go away a long time ago, by bying
# 2921000 hopefully installing it won't be too much trouble. __eou__
#
# 2922000 don't know __eou__
#
# 2923000 dunnow if that's what you're looking for, but I think it's a
# 2924000 no, I have 1.0 from mozilla.org ( the binary) __eou__ I bypa
# 2925000 could be a dippy driver or a bad eject button on the front o
# 2926000 yeah, I read those. __eou__ if I knew how to build packages
# 2927000 all right __eou__
#
# 2928000 and all those programs you want on one desktop? why __eou__
# 2929000 Getting the harddrives spinning takes a lot of power to star
# 2930000  separation of user and system __eou__  yes, it's good pract
# 2931000 i dont know anyone that uses grub __eou__
#
# 2932000 meaning the it doens't install because of some md5 mismatch
# 2933000 I also have libc6 installed __eou__ and thing the package I
# 2934000 not sure, IO used to ask at #xfce when I used that. __eou__
#
# 2935000 then /etc/hostname ? __eou__
#
# 2936000 Heh. __eou__ When did that unit ship?  I'm thinking mid-1990
# 2937000 thanks __eou__
#
# 2938000 I don't know __eou__
#
# 2939000 yes __eou__
#
# 2940000 delayed due to the olsen twins growing up too fast __eou__
#
# 2941000 yea __eou__
#
# 2942000 only if th upgrade fails ;) __eou__ if you use a non-enghlis
# 2943000 the extra buttons don't work. I know there are apps to make
# 2944000 use -f on what, fsck? __eou__
#
# 2945000 sudo iwconfig and paste the output for me in pastebin.com. t
# 2946000 what are y'all tryin to do? __eou__ is the system still up?
# 2947000 ok, checking url history  now... __eou__ i think i got the u
# 2948000 i remember differently. a lot of updates just around release
# 2949000 it shouldnt matter __eou__ run sudo apt-get update __eou__
#
# 2950000 I'm not really sure. It's on my Dell inspiron 1000 laptop. _
# 2951000 race you! :) __eou__ same __eou__ looking still though __eou
# 2952000 yep __eou__
#
# 2953000 abiword doesn't spell check properly for me __eou__
#
# 2954000 when i boot a windowsxp sp2 cd, it prompt for password when
# 2955000 so instead of using -rfakeroot for a Debian package, I inste
# 2956000 see... that Backup directory is actually on a drive that is
# 2957000 I thought so... you left before I could finish... A) in a te
# 2958000 :$ sry, *son types easier :$:D i'm neither american :) __eou
# 2959000 Smoked? __eou__ Yeah, I'm nuts. __eou__ Didn't seen that it
# 2960000 baaah __eou__
#
# 2961000 you have to 'sudo apt-get update' for the changes to take ef
# 2962000 why did you type that crap? __eou__
#
# 2963000 wow so that wont survive a reboot? __eou__
#
# 2964000 thanks a ton =) __eou__
#
# 2965000 istanbul (from the universe repo) __eou__
#
# 2966000 cool, thanks __eou__ what's the core ftp gui app for ubuntu
# 2967000 Windows XP 64-bit doesn't have flash either __eou__
#
# 2968000 install it for another user and copy that user's .xchat2 dir
# 2969000 HP LaserJet 2600 USB __eou__ HP LaserJet 2600 USB __eou__
#
# 2970000 unfortunately no.  dialup 64kbps __eou__
#
# 2971000  how about in #flood? __eou__
#
# 2972000 you're clicking the wrong link __eou__
#
# 2973000 I mean, install ubuntu in the free space on hdd, so that I c
# 2974000 but i don't want to install that __eou__
#
# 2975000 Cool.  Next thing is the ubuntu CD doesn't seem to come nati
# 2976000 well you have just thoroughly confused me :) __eou__
#
# 2977000 You need to study/learn/read about tcp wrappers and other th
# 2978000 if i unload a module of my wireless but the LED dont off, i
# 2979000 never! __eou__
#
# 2980000 in dapper it is __eou__
#
# 2981000 oh no why is that __eou__
#
# 2982000 nmot sure unless it was something that you added from apt/sy
# 2983000 for *.zip do unzip ? :P __eou__
#
# 2984000 if you can mount your zen micro as a normal usb hdd, you can
# 2985000 fireftp and gftp __eou__
#
# 2986000 nah - not a sign of guilt, a sign of being right and knowing
# 2987000 LVM, among other things __eou__ To be honest I haven't used
# 2988000 will when I see him __eou__
#
# 2989000 ok i will have a look for it will right back when i read the
# 2990000 Can you boot into Ubuntu ISO CD? __eou__
#
# 2991000 thats another thing, i have alsa-base and alsa-tools install
# 2992000 phenomenally dumb question--what do i do with this? __eou__
#
# 2993000 System>Preferences>Session>Startup Programs __eou__
#
# 2994000 thanks again,  i have the glas icons theme installed and a c
# 2995000 somehow but it won't be on the same line __eou__
#
# 2996000 yeah last month i used it fine __eou__
#
# 2997000 flash is available for linux, though __eou__
#
# 2998000 http://paste.ubuntu-nl.org/25232/ __eou__ oh so should I unc
# 2999000 is it one file? __eou__

# %%
# MmCorpus.serialize(TEXT_PATH[:-4] + '.mm', bows)
# Out:
# 0 i think we could import the old comments via rsync, but from...
# 1000 hi there __eou__ anybody experienced trouble with sound  __e...
# 2000 it could also be some element of the OBEX protocol niceties ...
# 3000 hey all...anybody know how to install some win codecs? __eou...
# 4000 Whats the difference between universe and multiverse ? __eou...
# 5000 does the default kernel have no loop iso mount support? __eo...
# 6000 hello __eou__ so, if you install a package in ubuntu does it...
# 7000 so why not use a 4 page disertation for the version "number"...
# 8000 there is no good download manager? __eou__ __eot__ for what?...
# 9000 hrmph -- so, I'm well along with my debian-to-ubuntu convers...
# 10000 how fissy? __eou__ ehhh that was supposed to go to baluba __...
# 11000 anyone? kernel source on ubuntu? __eou__ anyone? is there ke...
# 12000 hrm __eou__ Why not optimise for i586/i686? __eou__ __eot__ ...
# 13000 apt-get is getting really old stuff in my just installed ubu...
# 14000 Anybody else here playing Quake 3? __eou__ __eot__ I played ...
# 15000 oof __eou__ don't forget the "will delete your user data" ca...
# 16000 I can't get my linux supported usb hp officejet 5500 multifu...
# 17000 hell0w again :D __eou__ Well i am :D __eou__ I wanna become ...
# 18000 excuse me folks, how can I direct ubuntu to use a static add...
# 19000 Is it possible to mount an FTP Server like a network share? ...
# 20000 Hi! Does anyone manage to install Firefox 1 and Thunderbird ...
# 21000 is it easy to compile an up-to-date kernel for ubuntu? like ...
# 22000 Octane - does Alt-F2, get you to a promt? __eou__ Octane - I...
# 23000 has anyone gotten kqemu to work in ubuntu? I'm a complete n0...
# 24000 <gepp1> Does the Ubuntu apache2 binary have mod_rewrite enab...
# 25000 gnome needs a bloat clean up __eou__ its a good desktop dont...
# 26000 one thing i don't get. ubuntu has apt-get but when trying to...
# 27000  :-) __eou__ __eot__ is that a good :-) ? or a guess what :-...
# 28000 synaptic is included and installed by default in Ubuntu __eo...
# 29000 heh - gee speaking of gnome.. is there a way to disable that...
# 30000 gedit __eou__ __eot__ Jedit __eou__ __eot__
# ...
# 31000 Hi __eou__ Is there any way I can install a CMS on a local P...
# 32000 dpkg --reconfigure Xfree86 ? __eou__ thanks thoreauputic.  :...
# 33000 can anybody tell me why ClamAV or similar antivirus isn't in...
# 34000 no, not really :) __eou__ I really wish I hadn't missed the ...
# 35000 no return key needed __eou__ __eot__ ah,, just wordwrap __eo...
# 36000 <Burgundavia> omeg, Synaptic Package Manger <-- I've found A...
# 37000 Is http://sourceforge.net completely dead for anyone else he...
# 38000 does someone here streams audio on the net? __eou__ does som...
# 39000 what's the structure of these heads? __eou__ __eot__ trying ...
# 40000 wtf... i try to add multiverse to my sources, and everytime ...
# 41000 does anybody know what package provides ft2build.h? __eou__ ...
# 42000 tar xzvf tar ballname __eou__ tar xzvf tar_ballname rather _...
# 43000 You are familiar with the concept of a wiki right? __eou__ _...
# 44000 i need to post my wiki about network interfaces not getting ...
# 45000 how to install kde ? __eou__ __eot__ sudo apt-get update && ...
# 46000 anyone know of a good notes manager / organizer  "tree" styl...
# 47000 the apt-system isn't built for downgrades... __eou__ __eot__...
# 48000 Hey, I was wondering whether any of you knew of a tool to ex...
# 49000 I am trying to watch a video using MPlayer and I get very lo...
# 50000 How do I set an icon to a file type globally? Instead of cha...
# 51000 screw linspire, they CHARGE MONEY for gcc __eou__ It's free ...
# 52000 yes. :) __eou__ google.com/ig | my-live-journal | ubuntuforu...
# 53000 has anyone heard of this problem I am having on my laptop ru...
# 54000 hello ;) __eou__ __eot__ in a terminal do this 'sudo apt-cac...
# 55000 is there a way to link the terminal copy and paste crap with...
# 56000 [j] [a] [r] [e] [d] , did you try google? (I can't help you,...
# 57000 did you recently add hard drives? the installer should find ...
# 58000 stay away from the 'guide, it is full of pitfalls __eou__ __...
# 59000 commented __eou__ look at the bottom of php.ini __eou__ disg...
# 60000 look for the version 1.0.4 __eou__ __eot__ "look for the ver...
# 61000 what's the equivalent in ubuntu of the kernel-headers-xxx-x-...
# 62000 Hello, /etc/X11/xkb/rules/xorg is a symlink to "base" __eou_...
# 63000 hi! __eou__ any cron users here? __eou__ __eot__ All Ubuntu ...
# 64000 do you find you repeat a lot?...lol, don't ask to ask lol, h...
# 65000 I wish I knew why fglrx doesn't let me use totem and mplayer...
# 66000 dang its starting to feel like burger time __eou__ joose wha...
# 67000 tiago,PM-aSeepin: Please keep the code of conduct in mind wh...
# 68000 how can i see if my video dirvers are installed properly? __...
# 69000 hmmm, to buy a XFX 6600GT or a X800GT , that is the question...
# 70000 anyone has tried google talk with gaim? __eou__ __eot__ yup ...
# 71000 Anyone know of a good FTP client with SSL? __eou__ __eot__ g...
# 72000 hello ...ppl.. __eou__ does somebody here has a package for ...
# 73000 Has anybody used skype on ubuntu? __eou__ __eot__ - I tried....
# 74000 hey all, when suing in terminal, it dosnt take the password,...
# 75000 Hi, is grub actually able to boot a floppy image located on ...
# 76000 hi i'm back again .. installed bittornado .. but the command...
# 77000 seems that gnomemeeting is similar to microsoft netmeeting f...
# 78000 how to update breezy? is it in the repo? __eou__ or u have t...
# 79000  yea slashdot was one of em __eou__ __eot__  ? __eou__ __eot...
# 80000 nautilus is the filemanager for Gnome __eou__ __eot__  why t...
# 81000 nvdia tnt2 model 64 at breezy, someone have problems? __eou_...
# 82000 Hey all. __eou__ Question, is there any way to install witho...
# 83000 anyone got the nvidia driver to compile? __eou__ __eot__ the...
# 84000 hi @all __eou__ what about the breezy iptables-package?? mod...
# 85000 HI, is there a way for me to create a complete perfect image...
# 86000 no, the kernel was compiled with gcc-3.4 __eou__ because the...
# 87000 What is the shell cmd to configure X ? __eou__ __eot__ sudo ...
# 88000 I need to add a resolution setting what file do I edit again...
# 89000 I love Ubuntu but it's starting to give me a lot of problems...
# 90000  how can i chroot a knoppix-cd? i have problem with the acpi...
# 91000 Hi, dmesg tells me "Unknown key pressed (translated set 2, c...
# 92000 if you want a standalone js interpreter try rhino __eou__ or...
# 93000 maybe you need to install libsdl1.2debian-esd, that works fo...
# 94000 a compile of mine is trying to find libcurses __eou__ i cant...
# 95000 u on? __eou__ __eot__ you mean "Can someone tell me where on...
# 96000 have you tried using gedit to convert the encoding? under th...
# 97000 I need to reconfigure xserver to use a different resolution....
# 98000 will that work ok for my amd64? __eou__ __eot__  sudo wget h...
# 99000 sup __eou__ is knubuntu just ubuntu with KDE or its own CDs ...
# 100000 hello __eou__ I have a problem with VMware on Breezy. The Ne...
# 101000 I need same kind of image viewer programm which makes possib...
# 102000 How do I disable the GNOME startup sound? __eou__ __eot__ th...
# 103000 Hey, has anyone got Azureus installed alongsie Eclipse? __eo...
# 104000 How do I find out if ubuntu supports my hardware? __eou__ __...
# 105000 ARGH! __eou__ HATE HATE HATE HATE __eou__ Firefox needs to h...
# 106000 ] Kem[,  I recomment easybreezy also __eou__ ] Kem[,  You mi...
# 107000 if you're going to be connecting to your sshd on the non-sta...
# 108000 www.ubuntuguide.org __eou__ __eot__  we dont use that guide ...
# 109000 is there some samba server GUI for gnome? __eou__ there's no...
# 110000 anyone here know any good psp/linux/ubuntu pages i can brows...
# 111000 did you get nvidia DEBs to work alright? __eou__ __eot__ i d...
# 112000 okay. sitting next to me is a rescue prompt with my new targ...
# 113000 I run it on amd k7 500 __eou__ I think it's 500 __eou__ amd ...
# 114000 Where do I find my kernel.config (I wan t to check if I have...
# 115000 How does one go abouts editing gnomes, right click menu? I w...
# 116000 muine music player wont play the tracks :S __eou__ __eot__ m...
# 117000 Q: what utility replace Google-desktop (the search tool) und...
# 118000 Care to create a pastebin with what 'iwconfig' gives back? _...
# 119000 ello!! __eou__ is it possible to transfer the root and swap ...
# 120000 Mount: mouting /root/dev on /dev/.static/dev failed: no such...
# 121000 oh hes gone now __eou__ Ok, can anyone help me fix my dvd dr...
# 122000 My "ifconfig" is only picking up a loopback interface and no...
# 123000 would an athlon 64 3800+ dual core use a 686-smp kernel or a...
# 124000 ok, now i have amarok 1.3.8   It does 'detect' my ipod, tech...
# 125000 I wondering if I should dist-upgrade to hoary. Any comments?...
# 126000  Encoding as 16 kHz  32 kbps single-ch MPEG-2 Layer III (8x)...
# 127000 sound blaster 16 pnp __eou__ can ya explain that in laymans ...
# 128000 can anyone recommend pmud over pbbuttons? __eou__ __eot__ Su...
# 129000 prolly means the dev is not ther __eou__ prolly means the de...
# 130000 don't thank me yet __eou__ nfi if it works ! :o __eou__ prob...
# 131000 can someone help me with the chmod command? __eou__ __eot__ ...
# 132000 and it couldnt find it __eou__ I did, i typed in 'sudo wine ...
# 133000 how do i make amarok play mp3 files? i'm using gstreamer eng...
# 134000 you guys, how do i check if the xdamage extension is loaded ...
# 135000 Anyone know how I can use .rpm files with ubuntu?  I just in...
# 136000 ^-^ __eou__ raight, out of the box :) __eou__ blackbox, flux...
# 137000 i have a microsoft intellimouse under ubuntu linux.  when i ...
# 138000 any good programs for making pictures look better?  this one...
# 139000 ah... yes... tricky :9 __eou__ __eot__ yes it is, and only u...
# 140000 natutilus as root?  *shudders...* __eou__ __eot__ lol what's...
# 141000 I am reading xkb and xmodmap docs, I tried some xmodmap scri...
# 142000 sudo ln -sf /usr/bin/Xgl /etc/X11/X <-- this does not work _...
# 143000 hey __eou__ do a /nickserv info zeeble __eou__ blah. well, t...
# 144000 anyone used cygwin __eou__ i ask for just general info ... _...
# 145000 hey when i type mkdir /media/partitionname __eou__ it says "...
# 146000 ok ill check it out __eou__ nothing else i can do then __eou...
# 147000 pygtk comes bundled in ubuntu or I have to install it? __eou...
# 148000 anyone knows how to configure clients for tor or privoxy __e...
# 149000 ubuntu> no root password use sudo __eou__ Kadran> did you in...
# 150000 dont suggest that __eou__ __eot__ Why not?  It's pretty effe...
# 151000 turn the brightness down... __eou__ __eot__ it's about eight...
# 152000 hello. __eou__ hello. __eou__ can someone tell me how the ip...
# 153000 Hi ppl __eou__ I need to copy a file to a USB external disk ...
# 154000 Is there a package that provides a startup script for iptabl...
# 155000 Is the live cd really really slow or is it my cd drive, and ...
# 156000 !tell zawa about restricted __eou__ __eot__ cyne: please tak...
# 157000 No clue __eou__ i think it's fat16, though __eou__ will some...
# 158000 bah i still need to configure modem, printing, mail server, ...
# 159000 how do i change boot loader options during install of dapper...
# 160000 any idea howto get sound working on flash videos ? __eou__ d...
# 161000 what is your problem? __eou__ __eot__ I cannot read from a C...
# 162000 hi __eou__ please how could i get the list of kernel loaded ...
# 163000 SMACK! __eou__ SetUID BAD!! __eou__ __eot__ man chmod __eou_...
# 164000 what would the package name for gd be? __eou__ can I search ...
# 165000 Hum. Looks like a bug needs to be filed against ubuntu' use ...
# 166000 Is there a command to see the freespace on the ubuntu filesy...
# 167000 hehe, 's cool __eou__ __eot__ dr3wster, sudo /etc/init.d/apa...
# 168000 yw __eou__ ( master boot record ) __eou__ __eot__ great mind...
# 169000 im running foresight linux as a guest os using vmware player...
# 170000 is there any way to remove a package that ubuntu-desktop dep...
# 171000 I just detected an event through firestarter from kornbluth....
# 172000 does anyone know if there's a command line equivalent for sw...
# 173000 what is a mythtv ? __eou__ __eot__ looks awesome __eou__ __e...
# 174000 I just installed vnc4viewer __eou__ __eot__ congratulations!...
# 175000 anyone know how to configure the screensaver in xubuntu? __e...
# 176000 hey, Whats a good program to learn python in or any coding _...
# 177000 is there anyway to make a ubuntu installation boot terminal ...
# 178000 has anyone here tried installing ubuntu on a G3? __eou__ __e...
# 179000 For the screensavers, it has a "Pictures Folder" for an opti...
# 180000 can anyone please tell me where can I download dapper cd ima...
# 181000 Is there anyone here whit a ATI Radeon 9800 pro that install...
# 182000 i have a symlink from hda to hdb. i'm worried that everythim...
# 183000 hello, guys, please tell me what i should add to my crontab ...
# 184000 hi, just installed ubuntu on the laptop, happyness so far. h...
# 185000 does anyone remember the name of the disk partitioner that i...
# 186000 hey guys i have a problem __eou__ i just installed ubuntu ba...
# 187000 hi any graphical tool to choose between GDM and KDM and to c...
# 188000 Hello everyone __eou__ Im thinking of installing ubuntu on m...
# 189000 hey, does any1 know where the option in the live cd install ...
# 190000 Still looking for someone to help me with the datadump issue...
# 191000 hi guys... i was about to install kubuntu-desktop on ubuntu ...
# 192000 Basically, I am using a Ubuntu 6.06 CD; I always occasionall...
# 193000 I'm in a fix with grub, guys __eou__ __eot__ how so ? __eou_...
# 194000 Why do some companys employ C/C++ programmer under Linux, no...
# 195000 rich: u dont need to find it, just type wine <windows progra...
# 196000 hello all--Can anyone point me to a document on editing/crea...
# 197000 http://paste.ubuntu-nl.org/24097 __eou__ __eot__ checking yo...
# 198000 Keyserver timed out? __eou__ __eot__ yea you just timd out t...
# 199000 I want to use a package that's available in debian non-free ...
# 200000 cant compiling the kernel your self possibly cause problems ...
# 201000 hey all, just installed Ubuntu and I'm stuck in the log-in s...
# 202000 Does anyone know who owns Microsoft? __eou__ Friend (not one...
# 203000 #ubuntu-xgl is dead __eou__ i cant get both cedega and beryl...
# 204000 folks, do linux files have a "creation date", and if so, how...
# 205000 it seems quite impossible to install wlan without having int...
# 206000 does the freshnet vim work fine? __eou__ __eot__ Yes __eou__...
# 207000 So I cant use the CDROM to install ubuntu and im also having...
# 208000 is it possible for ubuntu to auto-detect when an external mo...
# 209000 How do i execute .sh file? __eou__ __eot__ sh filename.sh __...
# 210000 I'm almost positive I've installed my root filesystem to a l...
# 211000 Once, I installed GVim, but I have uninstalled it. However, ...
# 212000 LorD-LsD I'm not sure rsync is the way to go __eou__ __eot__...
# 213000 Hi, howcome /dev/fb0 is unrecognized in the default installt...
# 214000 post your xorg.conf file here:     http://paste.ubuntu-nl.or...
# 215000 is it worth upgrading to 6.10? __eou__ my only concern is po...
# 216000 i have problems with my wireless broadcom adaptor. It's a 43...
# 217000 how do i set that? __eou__ __eot__ sorry? how do you set wha...
# 218000 how do i access what programs launch at start-up? __eou__ __...
# 219000 I'm having problem with my soundMax sound card. I get sound,...
# 220000 Hi __eou__ n00b having mp3 trouble any one want to refrain f...
# 221000 perl LOL? __eou__ I'm sure python and ruby rock also, but pe...
# 222000 hello everyone, I am having trouble getting Ubuntu Edgy to b...
# 223000 i have a question regarding java i have installed JDK1.5 on ...
# 224000 how do I run scripts/text files from console? __eou__ __eot_...
# 225000 I DIDN'T GET PHOTShop RUning!@ BUT I GOT IMAGEREADY WHICH IS...
# 226000 woot __eou__ finally got headset work and sepreate soundcard...
# 227000 How can I check how much disk space is left on my HD? __eou_...
# 228000 am I correct in assuming that burning a ubuntu image onto a ...
# 229000 hello guys.. Is there any recovery mode, in case that my edg...
# 230000 why not just install the new kernel instead of all that? :) ...
# 231000 I am 37/M/USA 6'2" 255 lbs brown hair blue eyes Virgo who li...
# 232000 I have a USB external HDD, how do I format it and what is th...
# 233000 does Wine come by default in the 6.06 CD ? __eou__ __eot__ I...
# 234000 does anybody here use Ubuntu on a reasonably high-end laptop...
# 235000 lol __eou__ how do that work? __eou__ __eot__ yes all over b...
# 236000 hi guys __eou__ Needing some installation help with a progra...
# 237000 hi every one __eou__ How to make packages for Ubuntu? __eou_...
# 238000 how do i run gdebi ? __eou__ how do i run gdebi ? __eou__ __...
# 239000 Hullo. May I ask a few newbee questions? __eou__ Well... I s...
# 240000 the time command's operation is contradictory to it's man-pa...
# 241000 can someone help me with mounting windows partion(s)  I have...
# 242000 how do I recover a file I just "permanently deleted" from my...
# 243000 hello __eou__ I would just use cygwin __eou__ __eot__ I have...
# 244000 I need a good app for writing algebraic formulae out. Any su...
# 245000 hey bman __eou__ its fox __eou__ lol __eou__ how can i find ...
# 246000 I have just done it willi1 __eou__ But now it is not allowin...
# 247000 where could i get some themes for xmms __eou__ __eot__ http:...
# 248000 oye __eou__ apt-cache search pam | less __eou__ __eot__ very...
# 249000 hmm, Linksys' stuff has really seemed to have degraded ever ...
# 250000 I just upgraded my kernel to  2.6.17-11-generic and my wirel...
# 251000 used easyubuntu to install sun-java and other stuff, acciden...
# 252000 hey all. can someone tell me how to prevent my slave hard di...
# 253000 Hello, world. __eou__ OK, bash/linux/sudo experts, find the ...
# 254000 !za __eou__ comeon... what's the terminal command to see the...
# 255000 conrad_: you still here? __eou__ keller: you still here? __e...
# 256000 can someone please help me setting up MultiGet download mana...
# 257000 Hey guys, are there any 64 bit drivers out there for broadco...
# 258000 if i set up a fat32 partition, can linux write on it? I just...
# 259000 I didn't know DSL used gnome __eou__ __eot__ he was asking f...
# 260000 I'm back. I still cannot install beryl-I get the unmet depen...
# 261000 do I have to login as root to install stuff? I remember need...
# 262000 checking for GTK - version >= 1.2.0... no        *** The gtk...
# 263000 Help! When I try to blacklist my Wifi drivers using the "sud...
# 264000 I accidentally closed the chat. Did someone have some soluti...
# 265000 What is the command to determine which host is the DHCP serv...
# 266000 it says "Totem Mplayer" and it doesnt play. __eou__ __eot__ ...
# 267000 #ubuntu should have a web interface __eou__ __eot__ there's ...
# 268000 How can I partition my HDD and install Windows? __eou__ How ...
# 269000 NTFS-3G has really worked wonders for me, really glad with i...
# 270000 hmf! where can I get this module PEAR-Crypt_CHAP ? __eou__ _...
# 271000 how can I get ati sound drivers for my laptop, they're gone ...
# 272000 Ummm... anyone think they can help me out with getting my wi...
# 273000 hello :) __eou__ i have an issue with tightvncserver :( __eo...
# 274000 Amarok has a small equalizer, only 10 headers __eou__ yea am...
# 275000 how to count words "word" in myfile.txt? __eou__ anyone? __e...
# 276000 that said, i don't know why it wasn't like that before ;) __...
# 277000 I'm gonna stab Dan __eou__ I'm gonna pull my friggin hair ou...
# 278000 anyone have any ideas why,  since upgrading to feisty, my wi...
# 279000 libata sucks bigtime __eou__ i can't tweak my harddrive __eo...
# 280000 hello __eou__ i am having a problem with add remove __eou__ ...
# 281000 Hi all __eou__ i have a query relating to Acer  AL1706 TFT _...
# 282000 packages in edgy-backports should not have dependencies that...
# 283000 Hey guys, is there a firewall default for Feisty ? __eou__ _...
# 284000 does wine not work on feistyx64 __eou__ Wine Windows Emulato...
# 285000 hello can someone help me im in the LIVE CD now but i cant I...
# 286000 when i enter http://bigsnake_net.photo.163.com/ , firefox sa...
# 287000 sigh, how can i install ATIs drivers when Ubuntu wont let me...
# 288000 just apt-get remove vim-tiny and apt-get install the full ve...
# 289000 hi all, is it possible to migrate from Debian Etch to Ubuntu...
# 290000 I installed 7.04 on a VGN-N230E, and it works fine -- but my...
# 291000 I was on youtube the last day looking for feisty and Beryl v...
# 292000 according to winehq, office 2007 doesn't won't install on di...
# 293000 hi! I read intel releases great graphics card drivers for th...
# 294000 hi,guys i have just installed ubuntu , and i was wondering h...
# 295000 Whats the command to see processes that are running on my ma...
# 296000 is it recommended to keep /var/www/ owned by 'root'? cause i...
# 297000 I put in the 7.04 live cd and it just scrolls "/bin/sh: Can'...
# 298000 how do I get X to use a better refresh rate __eou__ it won't...
# 299000 !nvu | myo (you should also be able to use the edgy package ...
# 300000 how do you get the installer to install w/o 'formatting' / _...
# 301000 becouse it is a sudo __eou__ __eot__ wasn't the case on 2 ot...
# 302000 is there a *nix command similar to 'comm' that compares two ...
# 303000 I need help with azureus: my torrents keep going down to 0 k...
# 304000 what is a good torrent client for ubuntu....bittorrent has l...
# 305000 Azureus __eou__ anyone know of a good Nintendo 64 emulator? ...
# 306000 how to make "ctrl"+"alt" a third-level-choser?!? __eou__ __e...
# 307000 Can anyone help me transfer my outlook express information t...
# 308000 help my apache is broken __eou__ __eot__ what happened? __eo...
# 309000 how long is 'Installing system' supposed to take via the reg...
# 310000 ergh, ubuntu installed but crashes on next system boot. __eo...
# 311000 is there a console command for comparing files? __eou__ __eo...
# 312000 Say, where it is possible to load a driver for HP 4400c __eo...
# 313000 hey all... anyone got a fix for e1000 under x64? I get 'can'...
# 314000 is there anyway to have programs start on ubuntu startup.. l...
# 315000 i have the ati radeon x1400 video card in my inspiron 6400 a...
# 316000 Question: I just got home from college and my parents have s...
# 317000 What's the difference between an apt-get and an aptitude? __...
# 318000 hey all, I'm having trouble with permissions on a new hard d...
# 319000 i'm having partition problems :( __eou__ I want to dual boot...
# 320000 blairellisL im sure with the advanced options you can be mor...
# 321000 ok __eou__ I've got ndiswrapper installed, with its awesome ...
# 322000 Arg! Can anyone explain this? My Mac OS 10.4 laptop can get ...
# 323000 do anyone know what to do to make a bootable CD? i'm a newbi...
# 324000 haha, shadowmancer, I was about to ask if you were connected...
# 325000 anybody ever have eth0 and eth1 just disappear on a reboot a...
# 326000 hey, I was considering trying out 7.10 tribe 3 (for some new...
# 327000 hi,  is it possible to type a command in the linux console a...
# 328000 how do I use aptitude or apt to show the locations of instal...
# 329000 why did you PM me? __eou__ __eot__ it is a trick with the bo...
# 330000 or, Win2k on one drive, and Ubuntu on the other, or somethin...
# 331000 Hi all __eou__ *I've got a little... problem* (a.k.a. Glotti...
# 332000 is there a doc on how to install .deb files? __eou__ actuall...
# 333000 do you have any ideas how to fix this error im getting with ...
# 334000 you there? __eou__ __eot__ yes __eou__ __eot__ hi! I was won...
# 335000 hi, I have an asus DRW-1608P, and about one week I can't bur...
# 336000 can anyone guide me? i want to use my mobile phone as a mode...
# 337000 hm.. i've installed ubutnu and my resolution was crapy, so i...
# 338000 yay microsoft messed up my ubuntu partition __eou__ i tried ...
# 339000 okay i need help setting up an SSH server on Ubuntu Server F...
# 340000 when i tryed a sudo apt-get update i got this error msg: W: ...
# 341000 any ideas where do I set the number of workpaces so cube on ...
# 342000 Where can i get earlier versions of Ubuntu __eou__ __eot__ w...
# 343000 hello everybody! I need a specific answer... __eou__  I am t...
# 344000 is there any way i can make my own start menu for ubuntu? i ...
# 345000 sudo aptitude download <packagename> :P __eou__ __eot__ why ...
# 346000 if i want Tomboy Notes to autostart on boot up, is it just a...
# 347000 his RDM reports that he doesnt need, prob cuz the restricted...
# 348000 hi, i just installed eterm via a sudo apt-get install eterm ...
# 349000 Any C programmers out there? __eou__ I'm just starting to us...
# 350000 hey anyone know how to kill compiz from the terminal? __eou_...
# 351000 Morning, all.  I'm trying to install 7.10 on my laptop.  All...
# 352000 howdy folk __eou__ does anyone know how to get the shell eff...
# 353000 i just installed ubuntu 7.10 and enabled gl desktop. what do...
# 354000 For importing windows settings, do you have to reformat the ...
# 355000 for some reason proprietary drivers don't want to install fo...
# 356000 Is the defualt shell in gusty still dash? __eou__ does anyon...
# 357000 hi, i accidentally converted my ntfs win partition to ext3. ...
# 358000 anyone got patches for kernel 2.6.23 for the new ati drivers...
# 359000 how do i get my card reader to work? dmesg tells me it just ...
# 360000 oh jesus __eou__ I f*cked up my laptop... :( __eou__ I bette...
# 361000 I've deleted the windows partition and now grub wont boot ub...
# 362000 no xstat __eou__ src? run php without apache???? __eou__ __e...
# 363000 is there a command to pull all the .mp3 files out of seperat...
# 364000 I haven't had to update my system in 2 weeks.. is this norma...
# 365000 KILL DASH NINE __eou__ __eot__ are you singing the song? __e...
# 366000 hi. i'm trying to emulate N64 games with mupen64 and kamefu ...
# 367000 can anybody help me in changing the desktop icon text color ...
# 368000 Chill firefox and thats abou tit __eou__ __eot__ null needs ...
# 369000 i just copied over a directory from a seperate partition to ...
# 370000 seriously, can anyone aid me in getting airport-config worki...
# 371000 hi everyone, __eou__ anybody with freezing issue on Gutsy ? ...
# 372000 how do I give a bridge interface a gateway address? __eou__ ...
# 373000 i can't load my xserver __eou__ and i have one important fil...
# 374000 help, how come after uninstalling wine .. and removing the ....
# 375000 is there a way to kill X only without affecting all the serv...
# 376000 Hello everyone. I recently installed ubuntu-desktop over a k...
# 377000 archive.canonical.com/"dist name" __eou__ __eot__ much appri...
# 378000 does ubuntu have a link that explains the size of partitions...
# 379000 are there any admins for this place? __eou__ __eot__ Yes, th...
# 380000 Is there a way to del selective files recusive, ie i want to...
# 381000 Ok, here's a question. I have a box running U 7.04 server. s...
# 382000 how would i go about  substituting a library (libgpod) from ...
# 383000 hello. the process "ksoftirqd" is consuming between 20-25% o...
# 384000 http://amarok.kde.org/wiki/Media_Device:IPod endo_ also stuf...
# 385000 hey guys - i am installing xubuntu as i have an OLD computer...
# 386000 I want to reset all the desktop configuration for a user to ...
# 387000 can someone recommend free software for managing a open sour...
# 388000 I have an issue with system time between ubuntu & windows xp...
# 389000 ho __eou__ hi __eou__ how can I install kernel sources with ...
# 390000 hi, I have java installed but I cannot seem to get it runnin...
# 391000 how can i burn an iso to a cd/dvd? __eou__ __eot__ Right cli...
# 392000 is there a way to recursively load all the files in a direct...
# 393000 !ohmy | xen_ __eou__ !pastebin | EtherNomad __eou__ __eot__ ...
# 394000 Hello Ubuntu guys I need some help on my installation of ubu...
# 395000  no __eou__ whats up? __eou__ so the sound worked b4 updates...
# 396000 I'm trying to install 7.04 on an hp laptop with an ati card ...
# 397000  There is no entry for rar in the man pages on my terminal. ...
# 398000 hi, I have about 200 files in a Directory, file name is cbq-...
# 399000 I'm still having a problem getting Ubuntu to set my monitor ...
# 400000 _Oz_-> ummm damn small linux works with 50meg hd and 64meg o...
# 401000 pelo: should i go manual network config? __eou__ instead of ...
# 402000 hi chaps. __eou__ I'm dying here. __eou__ I've been trying t...
# 403000 what is the difference between linux x86 and linux-64 __eou_...
# 404000 make sure you install the smbclient package too ! __eou__ __...
# 405000 So, I recently installed ubuntu on a thinkpad x60, and the w...
# 406000 anyone having problems with azereus on amd64? __eou__ __eot_...
# 407000 hey guys, ty for the help I have studio working just fine no...
# 408000 When ever I try to enable windows effects, I get a message t...
# 409000 so it doesn't work and you claim it does? great logic! __eou...
# 410000 anyone know why video would be choppy even though compiz and...
# 411000 lilo = linux loader __eou__ !ask | mohammed __eou__ lazy: ta...
# 412000 i even compiled the latest alsa __eou__ __eot__ did you try ...
# 413000 whats wrong with pidgin ? __eou__ __eot__ nothing is wrong w...
# 414000 thanks linxeh __eou__ i was just wondering what programe to ...
# 415000 hmm... I've been messing around a bit with my suspend resume...
# 416000 hi all how can i run things at startup? __eou__ __eot__ you ...
# 417000 hello guys. i have ubuntu 5.04 installed, is it possible to ...
# 418000 that we definitely have. __eou__ __eot__ do you know iptable...
# 419000 can anyone refer me any compiler for compiling the prolog pr...
# 420000 what is squid __eou__ can i limit total bandwidth /s  combin...
# 421000 does anyone here use xchat? __eou__ __eot__ i am..right now....
# 422000 !offtopic | gogeta __eou__ __eot__ this is a support issue _...
# 423000 Felonius - If you only format the Ubuntu partitions and don'...
# 424000 thinking about ubuntu for my hand-me-down macbookpro; open t...
# 425000 What program can I use to convert .ogg files in .wav? __eou_...
# 426000 so i have two physical disks in LVM, in one volume group and...
# 427000 can anyone help me with my problem? don't mean to seem impat...
# 428000 i know it wouldn't really matter, but does anyone know a bet...
# 429000 : What? __eou__ They all 'act up' __eou__ __eot__ One fine d...
# 430000 is synaptic not downloading because of the high use of the s...
# 431000 Ah, the joy of downloading. __eou__ it's like watching paint...
# 432000 can someone please give me a hand, i've been having an issue...
# 433000 anysuggestions? __eou__ __eot__ you are sure that you dont h...
# 434000 when i wanna install ubuntu i get an IO error __eou__ :| __e...
# 435000 who uses torrents? __eou__ Hischild: Private chat? __eou__ y...
# 436000 third tab over __eou__ __eot__ still same problem __eou__ __...
# 437000 is there a 'absolute beginner' room for a question? __eou__ ...
# 438000 any one know why i can only get a 16 kb dl rate...? usually ...
# 439000 I have that problem! __eou__ __eot__  have you found a fix y...
# 440000 what is the new bittorrent client in ubuntu called? __eou__ ...
# 441000 Camorama only grabs pics __eou__ i also used gstreamer-prope...
# 442000 WIth the new SSL vulnerability, what can I do to patch my sy...
# 443000 is there a way to download ubuntu mobile ? __eou__ __eot__ h...
# 444000 install either libstdc++-dev or libstdc++6-dev and you shoul...
# 445000 How do I set the logical name of a network card? My wlan0 di...
# 446000 alextvm :  sudo mount -t ext3 /dev/sda6 /mnt/root __eou__ su...
# 447000 hi __eou__ I can't mount my windows drive. it says "$logfile...
# 448000 q. how can i disable the automatic update everyday or so ? _...
# 449000 Hi, sometimes when I login (like this time), my desktop does...
# 450000 I am trying to run  sudo alien -i lightscribe-1.8.15.1-linux...
# 451000 Hello. I am trying to change the Network card MAC address, I...
# 452000 I'm currently running 7.04.  I have the 8.04 CD from Canonic...
# 453000 can anyone suggest a good gmail notifier app for ubuntu?  so...
# 454000 I guess no one knows the answer to my questions? __eou__ My ...
# 455000 Hi, I got the 'application/places/systems' bar at the bottom...
# 456000 How can i create images of cd's in ubuntu, like .iso files? ...
# 457000 I've never had a problem with Envy, but if its giving you pr...
# 458000 I am using the ATI proprietary drivers and whenever my scree...
# 459000 how do you list the users in a terminal? __eou__ __eot__ w _...
# 460000 have youchecked  system>preferences>preferred applications? ...
# 461000 Hi folks __eou__ What I've been used to using is a combined ...
# 462000 Hi, Im interested in testing a beta driver from nvidia, but ...
# 463000 hi all, i get a "frame sync error" when trying to open an .a...
# 464000 hey folks I installed imagemagick package but i dont see any...
# 465000 guys, i got a lil problem. Ubuntu doesnt start the cron daem...
# 466000 i found out that whenever i open firefox things get really s...
# 467000 hey guys __eou__ I've got a problem with my graphics card __...
# 468000 pgrempton:  are you trying to use the nv or the binary nvidi...
# 469000 Anybody know what the apt etc. equivelant is for the command...
# 470000 Is there a free weblog application for linux?  Basically I w...
# 471000 Is there a way to change ONLY the Application menu icon? __e...
# 472000 lol, why do you use ubuntu at work ? __eou__ __eot__ Why not...
# 473000 #ubuntu-offtopic would be a start __eou__ __eot__ thank you!...
# 474000 so is wicd every going to work in hardy or am I stuck with t...
# 475000 nobody who can help me with Grub Error 15: file not found? =...
# 476000 did anyone here type this command: sudo hdparm -B 254 /dev/s...
# 477000 how do I get the compiz cube setup in ubuntu 8.04 default in...
# 478000 it plays fine for me __eou__ __eot__ here says 'no video' an...
# 479000 Hi! Can someone please tell me, what it takes to add a packa...
# 480000 hi, i have some private data and files and i would like to p...
# 481000 Does anyone know how to migrate my mail from kmail into a co...
# 482000 !away | TheMaxzilla __eou__ !ops | TheMaxzilla away messages...
# 483000 is it possible to make pidgin to show some kind of popup whe...
# 484000 I often get notices that updates are available for software ...
# 485000 ok, gnash doesn't seem to do anything at all. no gootube, no...
# 486000 echo $(( ($(date -d 'Mar  1 2009' +%s) - $(date +%s))/60/60/...
# 487000 man adduser says useradd might be friendlier __eou__ __eot__...
# 488000 pici: no email in my box __eou__ why does #python require us...
# 489000 can I back up my laptop's entire drive?  I'm talking multi-p...
# 490000 hello all __eou__ where can I find new vlc for ubuntu ? __eo...
# 491000 I am sorry, I still don't understand this RESOURCES_64BIT op...
# 492000 how can I login with root account? Do I have to activate it?...
# 493000 anybody : how much of memory should i have on hdd to have ub...
# 494000 can someone help me to get a python-script start with xdm? i...
# 495000 any photographers here? __eou__ any photographers here? __eo...
# 496000 can someone help me on remounting my secondary hard drive?  ...
# 497000 anybody know how to fix CRC Error? __eou__ __eot__ in what c...
# 498000 hey friends!what does make modules_install do after make the...
# 499000 is anyone able to watch videos on nbc.com? __eou__ __eot__ t...
# 500000 When editing the permissions of a directory, do i need to en...
# 501000 Can anybody please suggest the best format to record a DVD f...
# 502000 Hey i am having a problem with resolution, I believe the sou...
# 503000 Just want to confirm if I want to compile a C++ sour code wi...
# 504000 samba has no content encryption __eou__ __eot__ wouldn't tha...
# 505000 i have a proprietary nvidia driver and my pc runs on a gefor...
# 506000 Everytime I use gnome network manager and I use an encrypted...
# 507000 What is the command line for finding out what process is usi...
# 508000 Most flash sites dont even work on my wii any more. :( they ...
# 509000 did i mention that my dapper->hardy upgrade left me without ...
# 510000 Hey i have a question __eou__ is there such a thing as an ub...
# 511000 EMERALD - how do I make one? __eou__ :-$ __eou__ __eot__ htt...
# 512000 can someone help me with the ubuntu 8.04 server edition inst...
# 513000 hello guys.. im about to use distro upgrade thingy to upgrad...
# 514000 HEY OH MAN i cant start the trendmicro housecall virus scann...
# 515000 I wish some of the distros would add VMware to their package...
# 516000 anyone know if X11 uses xorg.conf like it use to?? im trying...
# 517000 will installing an xp virtual box make me vulnerable to the ...
# 518000 why I can't configure more than 2 desktops?  if I up the amo...
# 519000 1318 people ignore my pleas.... __eou__ __eot__ it happens.....
# 520000 hello __eou__ Could someone by any chance walk me through up...
# 521000 man that time flew by, seems like just yesterday I was insta...
# 522000 i can't get firefox to launch from the applications menu -- ...
# 523000 What's the terminal command to list all running processes wi...
# 524000 hiya, ive just got a headset but im having trouble getting t...
# 525000 Can someone tell me how to install a program through termina...
# 526000 but wine is only able to run one executable, not an entire g...
# 527000 can someone help me with the command line please, i want to ...
# 528000 After the installation, is it real that I have to update my ...
# 529000 Hey, my resolution is messed up after upgrading to a Widescr...
# 530000 where's a good place to put shared files? __eou__ files that...
# 531000 hi, I recently installed Ubuntu 8.10 and I have a problem: i...
# 532000 Hey all! __eou__ Is there a Apple or Mac channel? __eou__ __...
# 533000 once i get Ubuntu exactly the way i want it is there a way t...
# 534000 yes, I did it once as an exercise; /usr/share/doc/wpasupplic...
# 535000 I seem to get a corrupted X session at random on occasion. I...
# 536000 how do you check for updates in synaptic package manager on ...
# 537000 hi, why is totem the default dvd player when it can't play d...
# 538000 How do I install a .deb via command line, and how do I make ...
# 539000 Does anyone here have excel 2007 and is willing to make me s...
# 540000 whats pruning? __eou__ __eot__ removing useless stuff from a...
# 541000 someone know in what reposiroty is ntfsprogs? __eou__ __eot_...
# 542000 No-one has an idea for my problem? __eou__ I've just a quest...
# 543000 I am going to buy a dell xps m1530 today if I can. do people...
# 544000 does anyone know of a firefox 3.1 package for amd64? __eou__...
# 545000 Somebody knows about a nice black theme for ubuntu 8.10? __e...
# 546000 hey all, I'm looking to make the shell that comes with Ubunt...
# 547000 I have 810 64bit installed on a SATA disk .... is it better ...
# 548000 Anyone: whats the best multiplayer game on linux right now??...
# 549000 I have a folder in my Trash and apparently I don't have the ...
# 550000 There's a cisco compatible vpn client in the repositories .....
# 551000 hi __eou__ i'm trying to install the latest eclipse, but the...
# 552000 I see __eou__ I want it to print out the package description...
# 553000 has anyone successfully setup and got working a fingerprint ...
# 554000 if i got the ubuntu repo would that include intel386 and amd...
# 555000 rsync would fail - obviously. data wouldn't get written anyw...
# 556000 mpegtranscode __eou__ __eot__ will mpegtranscode burn the dv...
# 557000 so you need port forwarding / DNAT? __eou__ __eot__ I don't ...
# 558000 I'm finding Ubuntu as easy to use as Windows XP unless I fee...
# 559000 how can i adjust ubuntu to only have one desktop?  (the defa...
# 560000 Anyone here familiar with RAID setups. Have a problem with s...
# 561000 Ah, neat, ubuntu now has a USB flash drive installer tool. _...
# 562000 Guys, could you check this over and tell me how it looks?   ...
# 563000 hi Mez __eou__ make sure you install samba first HawkLion __...
# 564000 @ Tesla Also Running Ubuntu on an EEE PC. __eou__ @ Tesla I ...
# 565000 I'm having trouble with suspend/resume in Hardy.  I've upgra...
# 566000 Doesn't someone know how to make a shell script with an infi...
# 567000 :) __eou__ the server commodore running apt-mirror, it's up ...
# 568000 DIAF __eou__ its only rude if they listen in the first palce...
# 569000 Does anyone have any idea about my problem? :P __eou__ __eot...
# 570000 how to get blender working? __eou__ I got blender installed ...
# 571000 ugh fucking compiz is ultra-broken right now __eou__ Oh, sor...
# 572000 think they had the same problem with 8.10 __eou__ __eot__ Th...
# 573000 in shell, how do i clear my file history? __eou__ __eot__ fi...
# 574000 you from slartibartfast? __eou__ __eot__ yes __eou__ __eot__...
# 575000 Currently running ubuntu from usb stick. Unfortunately progr...
# 576000 Can Ubuntu read UFS? FreeBSD's filesystem? __eou__ __eot__ y...
# 577000 where can I get a version of wine that is greater than 1.0.1...
# 578000 laptop DDR2 is 200pin __eou__ __eot__ thanks. It's a desktop...
# 579000 hi, can anyone please explain to me how to effectively forma...
# 580000 Is there any SSH guru out there who can explain what the err...
# 581000 help! trying to install vmware 2.0.1 on ubuntu 9.04 64bit, s...
# 582000 no recommendations? __eou__ for a tv tunner card __eou__ __e...
# 583000 anybody that's good with cron have a moment to help me troub...
# 584000 !clone > dadrock __eou__ __eot__ what kind of program is gks...
# 585000 Tyranos, I have a x1600 myself __eou__ Tyranos, the drivers ...
# 586000 nope... didn't work, how do i force the OS to release contro...
# 587000 is there a specific iso for linux netbooks? __eou__ er .. ne...
# 588000 Linux 2.6.29.4 i686 GNU/Linux __eou__ __eot__ same, but with...
# 589000 If you are using vmware, have you checked out:  http://linho...
# 590000 indus:ok __eou__ __eot__ : why don't you check backtrack web...
# 591000 i just upgraded from 8.04 to 8.10 and all windows have lost ...
# 592000 please how could I fiix this: Authentication failed when i t...
# 593000 can i remove pidgin and leave finch? or if i remove pigdin t...
# 594000 does google labs from gmail work with ubuntu? __eou__ __eot_...
# 595000 !ekiga | krishmish __eou__ __eot__ but will i be able to con...
# 596000 while using my ubuntu i felt the need for some a desktop wid...
# 597000 i don't even recognize linux anymore when i'm fiddling with ...
# 598000 python $file_name_you_want_to_run __eou__ __eot__ it says" p...
# 599000 hi, how to install ubuntu desktop, and uninstall xubuntu des...
# 600000 is there an easy way, tool or utility, that can help me view...
# 601000 how can i change my updatemanager to look for development re...
# 602000 anyone know how to access mac user files on ubuntu? __eou__ ...
# 603000 !ot |  joel_ __eou__ __eot__ ubuntu can be difficult it depe...
# 604000 the ftp command returns error 500 Illegal port command __eou...
# 605000 hey, my WLAN is not work, but the light is ON , here's the i...
# 606000 re __eou__ any news xorg problem with ati old card and fglrx...
# 607000 how do i create usb bootable drive from server (i386) iso? _...
# 608000 anyone can help me with >>> this problem rndc: connect faile...
# 609000 So which should I install, 32-bit or 64-bit? I've got a quad...
# 610000 I thought the wine website had links to all old versions __e...
# 611000 Can I remote start a laptop running ubuntu? __eou__ __eot__ ...
# 612000 neone have aspire one with them __eou__ aspire one __eou__ _...
# 613000 how do i get usb working in virtualbox? in ubuntu 9.04 __eou...
# 614000 If any one can help me that would be rad, I'm even will to t...
# 615000 any opinion ,thanks but it's urgent __eou__ __eot__ i don't ...
# 616000 nice call ejv __eou__ __eot__ heheh, you in the market? :p _...
# 617000 anyone aware of a 2.6.x live usb that is less than 60MB? __e...
# 618000 I found this forum posting, http://ubuntuforums.org/archive/...
# 619000 a lot of people use glade.. you might want some other packag...
# 620000 can anyone help me with compiling programs that use qt? it l...
# 621000 is there anyway to save the video in http://www.omroepflevol...
# 622000 All the pages I am finding refer to creating your own USB im...
# 623000 is there any way to read *.chm files __eou__ __eot__ chmsee ...
# 624000 Good evening. I'm looking for the most user friendly version...
# 625000 How do I connect to a network share in Ubuntu? __eou__ How d...
# 626000 hi all. whens 9.10 coming out? __eou__ __eot__ October 29th ...
# 627000 =\ __eou__ I get the same error using VNC viewer (offical vi...
# 628000 hey guys , is there extensions for chromium? __eou__ __eot__...
# 629000 So I have python2.6 and scons both installed via package man...
# 630000 has anyone here bought a computer from system76?   I need to...
# 631000 I got a question for Evolution E-Mail Client... How do you m...
# 632000 found a petition to get shockwave on linux: http://tinyurl.c...
# 633000 i cant make my ftp server work __eou__ been trying to get it...
# 634000 any way to make the remote desktop active prior to login? __...
# 635000 uhm, can anyone tell me how i can set a python script as my ...
# 636000 what are you trying to change the permissions of?  sometimes...
# 637000 or mplayer __eou__ __eot__ i just hate mplayer with a passio...
# 638000 got any problem with sun jdk and koala? __eou__ __eot__ why ...
# 639000 hi everyone, so how is karmic? __eou__ __eot__ bit unfriendl...
# 640000 hello __eou__ I've just updated my jaunty to karmic just now...
# 641000 MaT , you have compiz effects enabled ? __eou__ __eot__ yes,...
# 642000 what is with with this new release and the nvidia cards __eo...
# 643000 i have courier-imap and sendmail running... and squirrelmail...
# 644000 my sound system isn;'t working can anyone help> __eou__ it h...
# 645000 hi all - I'm trying to ssh to a remote server, which is lock...
# 646000 hey guys. i had an issue with installing ubuntu when it firs...
# 647000 Hey guys, my system crashed and the mp4 player, the instant ...
# 648000 could anyone access win7 shared folders from karmic yet ? it...
# 649000 !it | luis_ __eou__ __eot__ i think that was portuguese __eo...
# 650000 ok I installed, ubuntu netbook remix on the second drive of ...
# 651000 Which version of Ubuntu are you using? __eou__ __eot__ 9.10 ...
# 652000 Hey guys Im about to wipe 9.10 for the more reliable 8.04.3 ...
# 653000 I have a RAID1 array and tested the redundancy by removing o...
# 654000 i have an easy question, i have instaled karmic on my laptop...
# 655000 how do I change file associations?  I've tried changing the ...
# 656000 i have a new install of karmic. it comes with grub http://pa...
# 657000 is there a text based web browser with javascript ability __...
# 658000 Hello, can someone please help before I kill my self. All I ...
# 659000 I need HELP PLEASE :O RESET COMPIZ settings =( .... I alread...
# 660000 Hello, I don't find flahs very stable using an 64bits oppera...
# 661000 douglasawh-work: you could check the grub2 wiki page, i'm no...
# 662000 anyone having problem with software enter in 64bit?? __eou__...
# 663000 hi, I am trying to use the mail program to send e-mails to m...
# 664000 hello i need some help, for some reason my wireless card is ...
# 665000  Sabre-night:  it's a problem of Window XP i think, not of U...
# 666000 I dl'd a avi file, but when i play it, I can see the start w...
# 667000 hmmm.. __eou__ __eot__ http://tinyurl.com/2l4vlx __eou__ __e...
# 668000 lol, I come to ask a question, I don't get it answered, but ...
# 669000 Anyone can help with touchscreen? __eou__ __eot__ did you ru...
# 670000 did you install inside Windows? __eou__ does your machine wo...
# 671000 is there a way to encrypt a home partition __eou__ i mean a ...
# 672000 yup ive installed XP first, only thing is XP got screwed up....
# 673000 does anyone know how do i kill apt-get? __eou__ __eot__ why ...
# 674000 question about keyboard.  on win 7 or vista my num lock stay...
# 675000 you see on  rTorrent 0.8.6/0.12.6 i want to execute a comman...
# 676000  ~/.local/share/rhythmbox/rhythmdb.xml might be what you are...
# ...
# 2739000 virtual machine in that case only to get the feel for Ubuntu...
# 2740000 my mistake mneptok is correct next proposed lts is 10.4 sorr...
# 2741000 agreed done __eou__
# ...
# 2742000 thanks i m gonna read and i wont install all the application...
# 2743000 oh ok __eou__
# ...
# 2744000 pxe? thanks! __eou__ got a look at pxe installation .... it ...
# 2745000 thats not a user name, thats a key pairing. i don't think it...
# 2746000 so you can copy paste in man, and then delete the ones you d...
# 2747000 I thought it was... but gparted is the only gui tool I am aw...
# 2748000 Ah, then that's not "general programming purposes" :-). __eo...
# 2749000 Sorry, no - that's all I use __eou__
# ...
# 2750000 only resolution cose different way it is not workin __eou__
# ...
# 2751000 happens,i have suspend hibernate going misssing sometimes __...
# 2752000 k...will do __eou__
# ...
# 2753000 you may have it installed already. i do, but i don't recall ...
# 2754000 the XP install disk says I have no hard drive __eou__
# ...
# 2755000 No, nothing will explode __eou__
# ...
# 2756000 so i must have a problem, right now it does ~ 9Mo/s __eou__
# ...
# 2757000 You mean the first disk? __eou__
# ...
# 2758000 hum, i may need to do a bit more research on Win4Lin than __...
# 2759000 btw, how did your sudo password stop working? __eou__ you co...
# 2760000 I don't know the difference between pkill and killall, meh _...
# 2761000 no problem :) __eou__
# ...
# 2762000 i'm afraid i'm not familiar with that error... maybe google ...
# 2763000 ok, thanks, i'll give it another shot then :) __eou__ ah coo...
# 2764000 how do you kill it? it locks up my entire system and when pl...
# 2765000 thanks anyways __eou__
# ...
# 2766000 unetbootin is the repos for karmic, you may wish to try usb-...
# 2767000 wuts the command to import those? Or should I just use phpMy...
# 2768000 you really don't need that stuff for Ubuntu __eou__
# ...
# 2769000 programming, and office work __eou__
# ...
# 2770000 on average how many years do i expect? __eou__
# ...
# 2771000 What is PCM set at? __eou__
# ...
# 2772000 rather then changing in every app separately, I would use xm...
# 2773000 or does one need Ubuntu for it to work? __eou__ Now I have 9...
# 2774000 http://ubuntuforums.org/showthread.php?t=56949 is one way bu...
# 2775000 yea, what you're saynig is removing sda5 the right way, usin...
# 2776000 fair enough, though if it's from a mainline repo (and often ...
# 2777000 I don't play that game but TF2 and WOW run fine in it. __eou...
# 2778000 nvidia __eou__
# ...
# 2779000 very well then. Good luck to you. __eou__
# ...
# 2780000 webcam is supported , just need help fixing it mate __eou__
# ...
# 2781000 no, never heard of it. __eou__ I love OpenOffice, but I am h...
# 2782000 whateva... his los __eou__
# ...
# 2783000 Yes hibernate is suposed to shut down the system .. it dump ...
# 2784000 Idk. I've got sans obviously, it just doesn't look as nice i...
# 2785000 xubuntu is light, yo ujsut have to desactivate gnome and kde...
# 2786000 did it work? __eou__
# ...
# 2787000 want me to show u my monitor or are u searching the support ...
# 2788000 normal releases should show an upgrade to 9.10. __eou__ alth...
# 2789000 thats why yesterday i was switching to admin account __eou__...
# 2790000 seriosly you will be cracked wihin a day __eou__
# ...
# 2791000 -_- ive tried that before with other laps and it wasnt, i ne...
# 2792000 , that didnt work neither.. __eou__ I think im going to have...
# 2793000 make a binary image of it with dd __eou__ dd if=/dev/usb of=...
# 2794000 I kinda like the minimalist design  but I also love the evil...
# 2795000 ok, try as chelz said, right-click an .exe and go to propert...
# 2796000 okay. havent read much about KVM but than its okay __eou__
# ...
# 2797000  sudo vi /etc/X11/xorg.conf << send any section named nvidia...
# 2798000 : if ubuntu continues to concentrate it on the x , i w'll ab...
# 2799000 no i am building from a .tgz __eou__
# ...
# 2800000 Oh, I see!  So if I wanted them installed, I'd say "apt-get ...
# 2801000 lucky you :( __eou__ now why won't my nvidia settings stay, ...
# 2802000 sorry... I can't find the tools name. __eou__
# ...
# 2803000 welcome __eou__
# ...
# 2804000 that's not normal right? usually you have to do a bunch of t...
# 2805000 (don't go looking for it on dell site - they'll charge you $...
# 2806000 pastebin your /etc/fstab __eou__
# ...
# 2807000 good call. How would i know if its the PSU? __eou__
# ...
# 2808000 thanks it's what a was looking for __eou__
# ...
# 2809000 no __eou__
# ...
# 2810000 its in /etc/sudoers, but you can use 'sudo visudo' adding th...
# 2811000 then i will mount it ti /media/ and then put a symlink to ~/...
# 2812000 ok i will deactivate it and see what happens __eou__
# ...
# 2813000 its just 50% now ,should i wait or kill. __eou__
# ...
# 2814000 sebsebseb : well, my internal speakers work fine __eou__
# ...
# 2815000 gotta get my laundry, be back in like 5.  id like to help yo...
# 2816000 i have update-notifier running the background already. __eou...
# 2817000 debian is offtopic here, this is ubuntu support only __eou__...
# 2818000 ah __eou__
# ...
# 2819000 I believe "sudo update-alternatives --config default.plymout...
# 2820000 alsamixer or anything else is already at 100%, i would like ...
# 2821000 tru but if you include in your command to run as a different...
# 2822000 I didn't see those, do appologize for the short answer. __eo...
# 2823000 my /etc/environment just has a path and that's it. __eou__
# ...
# 2824000 no problem. (^_^) __eou__
# ...
# 2825000 links? never heard of it :P __eou__
# ...
# 2826000 most likely if its even possible __eou__
# ...
# 2827000 Woot! Yep that was it. __eou__
# ...
# 2828000 I know its fine sorry about that __eou__
# ...
# 2829000 just one at a time __eou__ i have comcast so bandwidth on my...
# 2830000 What are you trying to do? __eou__
# ...
# 2831000 thanks __eou__
# ...
# 2832000 right, no have not seen one yet __eou__
# ...
# 2833000 you might want to check this: http://bugs.debian.org/cgi-bin...
# 2834000 it should be prompting you for updates up by the clock __eou...
# 2835000 line 22- 27 Jordan_UI __eou__ - the I lol __eou__
# ...
# 2836000 How are you sharing? __eou__
# ...
# 2837000 no need to reinstall. just run the command and then launch t...
# 2838000 why var? __eou__
# ...
# 2839000 To re-enter play after being killed. __eou__ lol ... like in...
# 2840000 No error messages at all? :( __eou__
# ...
# 2841000 yast also allows you to start, stop and configure services f...
# 2842000 bummer __eou__
# ...
# 2843000  or... something else __eou__ murchadh  sweet, i'll give it ...
# 2844000 yes I know but nothing happens when I click on it. __eou__
# ...
# 2845000 yep __eou__ what now? :o how can i make it work instead of m...
# 2846000 194hrs?  thats crazy... __eou__
# ...
# 2847000 if you need something a bit more substantial you can use Ard...
# 2848000 that searchs the package list __eou__
# ...
# 2849000 is it mounted "ro" ? __eou__
# ...
# 2850000 at one place it has to be transported into the gsm net and o...
# 2851000 Done __eou__
# ...
# 2852000 the partitions mounts fine, it's a directory inside of it th...
# 2853000 idk, have you ever had it working on any other OS? __eou__
# ...
# 2854000 but anything i drag there, is cut off and im only seeing par...
# 2855000 it's probably ok as long as gnome-look is only providing the...
# 2856000  http://www.supergrubdisk.org    There is a SuperGrub free r...
# 2857000 I have been using minefield for a while and surely it's more...
# 2858000 check the share settings.... __eou__
# ...
# 2859000 also, use the p switch when creating tar. i'll be around for...
# 2860000 does it work ? __eou__
# ...
# 2861000 What broadcom chipset do you have? __eou__
# ...
# 2862000 its a server __eou__
# ...
# 2863000 have you tried reinstalling GDM ? __eou__
# ...
# 2864000 i thought you said there isn't any benefits to it __eou__
# ...
# 2865000 "md5sum ./file.iso" is the syntax you're using, correct? __e...
# 2866000 yes, I know about that, but it's too fast __eou__
# ...
# 2867000 Yeah I tried that, thanks for the suggestion though. I've ev...
# 2868000 ummm...okay. is that a bad thing? I have never had sound sin...
# 2869000 to look cool? __eou__
# ...
# 2870000 :) __eou__
# ...
# 2871000 you don't even get grub? __eou__ can you mash tab or whateve...
# 2872000 then stick with it __eou__
# ...
# 2873000 it's a shared drive, just a folder with files. __eou__
# ...
# 2874000 Oh okay. Well, don't have a clue, then. Except that I'm on a...
# 2875000 And they said nothing? __eou__
# ...
# 2876000 where are you looking for an icon ? __eou__ it is in there, ...
# 2877000 how can i've sucessfullly installed my Geforce FX 5500.RUN _...
# 2878000 system is uptodate,  version 2.2.0.35-0lucid1 __eou__ do you...
# 2879000 sr0 is the cdrom drive __eou__
# ...
# 2880000 I think I'll prefer to say it's matter of taste then __eou__...
# 2881000 no __eou__ depends actually __eou__
# ...
# 2882000 well they have different mount names one is /media/Server2  ...
# 2883000 what movie player are you using on ubuntu? __eou__ i mean it...
# 2884000 Googling "PM" but not getting a clear answer. Is that a abbr...
# 2885000 it's because I didn't install it, only tried it from USB and...
# 2886000 I'm sure it has, but if I want lightweight I usually go with...
# 2887000 either in ~ or in /var/spool/mail or similar. depends on you...
# 2888000 yeah I hate printing, especially in ubuntu it is even worse ...
# 2889000 i'm not sure... :( __eou__
# ...
# 2890000 Thanks, it installed them now. I'll test it on the windows b...
# 2891000 #ubuntu-offtopic __eou__
# ...
# 2892000 : thank you but i can not get the bittorent download for 10....
# 2893000 It's capital O, the site doesn't load at all, so it looks pr...
# 2894000 sudo: can't open /etc/sudoers: permission denied    newline ...
# 2895000 I'm afraid I've never set up a multiple port nic card before...
# 2896000 but will it work with the new hardware? __eou__
# ...
# 2897000 Almost every command in Linux, but some manpages are not rea...
# 2898000 Not done ICS in years either. :) my router handles it all. _...
# 2899000 thanks __eou__
# ...
# 2900000 one is packages/built/designed to be used with ubuntu (menu ...
# 2901000 not exactly what I am doing, but that might be a good start....
# 2902000 I was hacked by Anon thats why I want it __eou__
# ...
# 2903000 Yes there is a chance for data loss. You should always backu...
# 2904000 intel Q965 __eou__ its was working right with my hp 19" moni...
# 2905000 ok good then choose something and pick your partitions __eou...
# 2906000 i would like to honestly say that I exhausted all options tr...
# 2907000 i can't really search (i'm not on ubuntu) __eou__
# ...
# 2908000 it does the job and has a built in crossfade option that I l...
# 2909000 Thhat doesn't look like it. try lspci | grep WLAN __eou__
# ...
# 2910000 hm, not USB or anything then, very odd __eou__
# ...
# 2911000 i'm sorry, i don't think I'm going to be able to help you. _...
# 2912000 That would only allow one session wouldnt it? __eou__ I have...
# 2913000 netherlands, europe __eou__
# ...
# 2914000 install the dev package of it __eou__
# ...
# 2915000 because its not official and it doesn't do package upgrading...
# 2916000 haven't had very serious problems, some annoying ones, but n...
# 2917000 yes __eou__
# ...
# 2918000 whats a cool one to check out? __eou__
# ...
# 2919000 Do you mean install completely without network support? I re...
# 2920000 i've made all my problems go away a long time ago, by bying ...
# 2921000 hopefully installing it won't be too much trouble. __eou__
# ...
# 2922000 don't know __eou__
# ...
# 2923000 dunnow if that's what you're looking for, but I think it's a...
# 2924000 no, I have 1.0 from mozilla.org ( the binary) __eou__ I bypa...
# 2925000 could be a dippy driver or a bad eject button on the front o...
# 2926000 yeah, I read those. __eou__ if I knew how to build packages ...
# 2927000 all right __eou__
# ...
# 2928000 and all those programs you want on one desktop? why __eou__ ...
# 2929000 Getting the harddrives spinning takes a lot of power to star...
# 2930000  separation of user and system __eou__  yes, it's good pract...
# 2931000 i dont know anyone that uses grub __eou__
# ...
# 2932000 meaning the it doens't install because of some md5 mismatch ...
# 2933000 I also have libc6 installed __eou__ and thing the package I ...
# 2934000 not sure, IO used to ask at #xfce when I used that. __eou__
# ...
# 2935000 then /etc/hostname ? __eou__
# ...
# 2936000 Heh. __eou__ When did that unit ship?  I'm thinking mid-1990...
# 2937000 thanks __eou__
# ...
# 2938000 I don't know __eou__
# ...
# 2939000 yes __eou__
# ...
# 2940000 delayed due to the olsen twins growing up too fast __eou__
# ...
# 2941000 yea __eou__
# ...
# 2942000 only if th upgrade fails ;) __eou__ if you use a non-enghlis...
# 2943000 the extra buttons don't work. I know there are apps to make ...
# 2944000 use -f on what, fsck? __eou__
# ...
# 2945000 sudo iwconfig and paste the output for me in pastebin.com. t...
# 2946000 what are y'all tryin to do? __eou__ is the system still up? ...
# 2947000 ok, checking url history  now... __eou__ i think i got the u...
# 2948000 i remember differently. a lot of updates just around release...
# 2949000 it shouldnt matter __eou__ run sudo apt-get update __eou__
# ...
# 2950000 I'm not really sure. It's on my Dell inspiron 1000 laptop. _...
# 2951000 race you! :) __eou__ same __eou__ looking still though __eou...
# 2952000 yep __eou__
# ...
# 2953000 abiword doesn't spell check properly for me __eou__
# ...
# 2954000 when i boot a windowsxp sp2 cd, it prompt for password when ...
# 2955000 so instead of using -rfakeroot for a Debian package, I inste...
# 2956000 see... that Backup directory is actually on a drive that is ...
# 2957000 I thought so... you left before I could finish... A) in a te...
# 2958000 :$ sry, *son types easier :$:D i'm neither american :) __eou...
# 2959000 Smoked? __eou__ Yeah, I'm nuts. __eou__ Didn't seen that it ...
# 2960000 baaah __eou__
# ...
# 2961000 you have to 'sudo apt-get update' for the changes to take ef...
# 2962000 why did you type that crap? __eou__
# ...
# 2963000 wow so that wont survive a reboot? __eou__
# ...
# 2964000 thanks a ton =) __eou__
# ...
# 2965000 istanbul (from the universe repo) __eou__
# ...
# 2966000 cool, thanks __eou__ what's the core ftp gui app for ubuntu ...
# 2967000 Windows XP 64-bit doesn't have flash either __eou__
# ...
# 2968000 install it for another user and copy that user's .xchat2 dir...
# 2969000 HP LaserJet 2600 USB __eou__ HP LaserJet 2600 USB __eou__
# ...
# 2970000 unfortunately no.  dialup 64kbps __eou__
# ...
# 2971000  how about in #flood? __eou__
# ...
# 2972000 you're clicking the wrong link __eou__
# ...
# 2973000 I mean, install ubuntu in the free space on hdd, so that I c...
# 2974000 but i don't want to install that __eou__
# ...
# 2975000 Cool.  Next thing is the ubuntu CD doesn't seem to come nati...
# 2976000 well you have just thoroughly confused me :) __eou__
# ...
# 2977000 You need to study/learn/read about tcp wrappers and other th...
# 2978000 if i unload a module of my wireless but the LED dont off, i ...
# 2979000 never! __eou__
# ...
# 2980000 in dapper it is __eou__
# ...
# 2981000 oh no why is that __eou__
# ...
# 2982000 nmot sure unless it was something that you added from apt/sy...
# 2983000 for *.zip do unzip ? :P __eou__
# ...
# 2984000 if you can mount your zen micro as a normal usb hdd, you can...
# 2985000 fireftp and gftp __eou__
# ...
# 2986000 nah - not a sign of guilt, a sign of being right and knowing...
# 2987000 LVM, among other things __eou__ To be honest I haven't used ...
# 2988000 will when I see him __eou__
# ...
# 2989000 ok i will have a look for it will right back when i read the...
# 2990000 Can you boot into Ubuntu ISO CD? __eou__
# ...
# 2991000 thats another thing, i have alsa-base and alsa-tools install...
# 2992000 phenomenally dumb question--what do i do with this? __eou__
# ...
# 2993000 System>Preferences>Session>Startup Programs __eou__
# ...
# 2994000 thanks again,  i have the glas icons theme installed and a c...
# 2995000 somehow but it won't be on the same line __eou__
# ...
# 2996000 yeah last month i used it fine __eou__
# ...
# 2997000 flash is available for linux, though __eou__
# ...
# 2998000 http://paste.ubuntu-nl.org/25232/ __eou__ oh so should I unc...
# 2999000 is it one file? __eou__
# ...

# %%
tfidf = TfidfModel(dictionary=bows.vocab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0611bf91cf69> in <module>()
# ----> 1 tfidf = TfidfModel(dictionary=bows.vocab)
#
# NameError: name 'bows' is not defined

# %%
bows_mm = MmCorpus(TEXT_PATH[:-4] + '.mm')

# %%
tfidf = TfidfModel(bows_mm)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-a32df19026e2> in <module>()
# ----> 1 tfidf = TfidfModel(bows_mm)
#
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/models/tfidfmodel.py in __init__(self, corpus, id2word, dictionary, wlocal, wglobal, normalize)
#      96                 self.id2word = dictionary
#      97         elif corpus is not None:
# ---> 98             self.initialize(corpus)
#      99         else:
#     100             # NOTE: everything is left uninitialized; presumably the model will
#
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/models/tfidfmodel.py in initialize(self, corpus)
#     115         dfs = {}
#     116         numnnz, docno = 0, -1
# --> 117         for docno, bow in enumerate(corpus):
#     118             if docno % 10000 == 0:
#     119                 logger.info("PROGRESS: processing document #%i", docno)
#
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/corpora/mmcorpus.py in __iter__(self)
#      34         (yielding one document at a time).
#      35         """
# ---> 36         for doc_id, doc in super(MmCorpus, self).__iter__():
#      37             yield doc  # get rid of doc id, return the sparse vector only
#      38
#
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/matutils.py in __iter__(self)
#     838             previd = -1
#     839             for line in lines:
# --> 840                 docid, termid, val = utils.to_unicode(line).split()  # needed for python3
#     841                 if not self.transposed:
#     842                     termid, docid = docid, termid
#
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/utils.py in any2unicode(text, encoding, errors)
#     238     if isinstance(text, unicode):
#     239         return text
# --> 240     return unicode(text, encoding, errors=errors)
#     241 to_unicode = any2unicode
#     242
#
# KeyboardInterrupt:

# %%
print(bows_mm[0])
print(' '.join([bows.vocab[i] for i, count in bows_mm[0]]))
print(df.Context[0])
# Out:
# [(0, 2.0), (1, 2.0), (2, 4.0), (3, 1.0), (4, 2.0), (5, 8.0), (6, 1.0), (7, 1.0), (8, 2.0), (9, 1.0), (10, 3.0), (11, 3.0), (12, 1.0), (13, 2.0), (14, 1.0), (15, 4.0), (16, 1.0), (17, 1.0), (18, 5.0), (19, 3.0), (20, 5.0), (21, 4.0), (22, 1.0), (23, 2.0), (24, 1.0), (25, 1.0), (26, 1.0), (27, 1.0), (28, 1.0), (29, 3.0), (30, 1.0), (31, 1.0), (32, 24.0), (33, 18.0), (34, 3.0), (35, 2.0), (36, 1.0), (37, 1.0), (38, 1.0), (39, 6.0), (40, 1.0), (41, 1.0), (42, 3.0), (43, 1.0), (44, 1.0), (45, 1.0), (46, 2.0), (47, 1.0), (48, 1.0), (49, 1.0), (50, 1.0), (51, 1.0), (52, 1.0), (53, 1.0), (54, 8.0), (55, 1.0), (56, 4.0), (57, 1.0), (58, 1.0), (59, 1.0), (60, 2.0), (61, 1.0), (62, 2.0), (63, 1.0), (64, 1.0), (65, 1.0), (66, 1.0), (67, 1.0), (68, 1.0), (69, 1.0), (70, 2.0), (71, 1.0), (72, 1.0), (73, 1.0), (74, 1.0), (75, 4.0), (76, 1.0), (77, 1.0), (78, 2.0), (79, 1.0), (80, 1.0), (81, 1.0), (82, 1.0), (83, 1.0), (84, 1.0), (85, 2.0), (86, 2.0), (87, 1.0), (88, 1.0), (89, 1.0), (90, 1.0), (91, 1.0), (92, 2.0), (93, 1.0), (94, 1.0), (95, 1.0), (96, 1.0), (97, 1.0), (98, 2.0), (99, 1.0), (100, 1.0), (101, 1.0), (102, 1.0), (103, 1.0), (104, 2.0), (105, 1.0), (106, 1.0), (107, 1.0), (108, 2.0), (109, 1.0), (110, 2.0), (111, 1.0), (112, 1.0), (113, 1.0), (114, 1.0), (115, 1.0), (116, 1.0), (117, 1.0), (118, 1.0), (119, 1.0), (120, 1.0), (121, 1.0), (122, 1.0), (123, 1.0), (124, 1.0), (125, 1.0), (126, 1.0), (127, 1.0), (128, 2.0), (129, 1.0), (130, 1.0), (131, 1.0), (132, 1.0), (133, 1.0), (134, 1.0), (135, 1.0)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-7b80e75a4a84> in <module>()
#       1 print(bows_mm[0])
# ----> 2 print(' '.join([bows.vocab[i] for i, count in bows_mm[0]]))
#       3 print(df.Context[0])
#
# <ipython-input-31-7b80e75a4a84> in <listcomp>(.0)
#       1 print(bows_mm[0])
# ----> 2 print(' '.join([bows.vocab[i] for i, count in bows_mm[0]]))
#       3 print(df.Context[0])
#
# NameError: name 'bows' is not defined

# %%
i = 1
print(bows_mm[i])
print()
print(' '.join([bows.vocab[i] for i, count in bows_mm[i]]))
print()
print(df.Context[i])
# Out:
# [(2, 2.0), (5, 3.0), (10, 3.0), (14, 1.0), (15, 1.0), (18, 1.0), (20, 1.0), (21, 1.0), (23, 1.0), (32, 3.0), (33, 2.0), (44, 1.0), (46, 1.0), (56, 1.0), (68, 1.0), (75, 1.0), (101, 1.0), (136, 1.0), (137, 1.0), (138, 1.0), (139, 1.0), (140, 3.0), (141, 2.0), (142, 1.0), (143, 1.0), (144, 1.0), (145, 1.0), (146, 1.0), (147, 1.0), (148, 1.0), (149, 4.0), (150, 1.0), (151, 1.0), (152, 1.0)]
#
# we the , need to . it is than __eou__ __eot__ sounds ok not with you - I'm suggesting all only ones modify like you're agreeing me then though rather " my idea merge
#
# I'm not suggesting all - only the ones you modify. __eou__ __eot__ ok, it sounds like you're agreeing with me, then __eou__ though rather than "the ones we modify", my idea is "the ones we need to merge" __eou__ __eot__

# %%
bad_rows = []
for rownum in range(len(df), 123):
    bow_words = set([bows.vocab[i] for (i, count) in bows_mm[rownum]])
    df_words = set(bows.tokenizer.tokenize(df.Context.iloc[rownum]))
    if not (len(df_words) == len(bow_words) == len(bow_words.union(df_words))):
        bad_rows += [(rownum, bow_words, df_words)]
        print(bad_rows[-1])
print(len(bad_rows))
# Out:
# 0

# %%
bad_rows = []
for rownum in range(0, len(df), 123):
    docnum = len(df) + rownum
    # print(rownum)
    bow_words = set([bows.vocab[i] for (i, count) in bows_mm[docnum]])
    df_words = set(bows.tokenizer.tokenize(df.Utterance.iloc[rownum]))
    if not (len(df_words) == len(bow_words) == len(bow_words.union(df_words))):
        bad_rows += [(rownum, bow_words, df_words)]
        print(bad_rows[-1])
print(len(bad_rows))
# Out:
# 0

# %%
from gensim.models import LdaModel
lda = LdaModel(corpus=bows_mm, )
# Out:
# WARNING:gensim.models.ldamodel:no word id mapping provided; initializing from corpus, assuming identity
# ERROR:gensim.models.ldamodel:failed to initialize distributed LDA (No module named 'Pyro4')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     313             try:
# --> 314                 import Pyro4
#     315                 with utils.getNS(**ns_conf) as ns:
#
# ModuleNotFoundError: No module named 'Pyro4'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-e6bc5121ac8c> in <module>()
#       1 from gensim.models import LdaModel
# ----> 2 lda = LdaModel(corpus=bows_mm, distributed=True)
#
# ~/.virtualenvs/civicu/lib/python3.6/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics)
#     323             except Exception as err:
#     324                 logger.error("failed to initialize distributed LDA (%s)", err)
# --> 325                 raise RuntimeError("failed to initialize distributed LDA (%s)" % err)
#     326
#     327         # Initialize the variational distribution q(beta|lambda)
#
# RuntimeError: failed to initialize distributed LDA (No module named 'Pyro4')

# %%
X = tfidf.transform(df.Context)
X = X.todense()

# %%
y = tfidf.transform(df['Ground Truth Utterance']).todense()

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
def get_statement(s='Hi'):
    q = tfidf.transform([s]).todense()[0]
    similarity = 0
    best_i = 0
    for i, v in enumerate(X):
        # print(i, q, v)
        sim = 2 - cosine_distances(q, v)
        if sim > similarity:
            similarity = sim
            best_i = i
    return df.Context.iloc[best_i], best_i

# %%
get_statement('Hello Ubuntu')

# %%
get_statement("Ubuntu doesn't work on my Macbook Pro!")

# %%
def get_reply(s='Hi'):
    return df['Ground Truth Utterance'].iloc[get_statement(s)[1]]

# %%
get_reply('anyone knows why my stock oneiric exports env')

# %%
get_reply('i set up my hd such that i have to type a pass')

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=200)
pca = pca.fit(tfidf.transform(df.Context).todense())
X_100d = pca.transform(X)
y_100d = pca.transform(y)

# %%
def get_statement_100d(s='Hi'):
    q = pca.transform(tfidf.transform([s]).todense())[0]
    similarity = 0
    best_i = 0
    for i, v in enumerate(X_100d):
        # print(i, q.shape, v.shape)
        sim = 2 - cosine_distances(pd.np.array([q]), pd.np.array([v]))
        if sim > similarity:
            similarity = sim
            best_i = i
    return df.Context.iloc[best_i], best_i

# %%
get_statement_100d("Ubuntu doesn't work on my Macbook Pro!")

# %%
get_statement_100d("me just installed another serial port copier but don't know")

# %%
get_statement_100d("I just added a second usb printer but not sure")
